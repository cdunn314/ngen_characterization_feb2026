# %% [markdown]
# # Activation Foil Analysis: LaBr Detectors
#
# This notebook processes the calibration data from a LaBr detector to energy calibrate the detectors and determine total detector efficiencies. Then, LaBr measurements of activation foils irradiated during the run with a D-T neutron (14.1 MeV) generator are used to determine the average neutron rate during the run.

# %% [markdown]
# ## Obtaining the Data
# First, the NaI detector measurement data is obtained from Zenodo and extracted

# %%
import numpy as np
from datetime import datetime
import json

# %%
from process_foil_data import get_data
check_source_measurements, background_meas, foil_measurements = get_data(download_from_raw=True,
                                                                         h5_filename='activation_data.h5',
                                                                         detector_type='NaI')
# Out:
# /home/cdunn314/libra/ngen_characterization_v2/neutronics
# Read in properties of Aluminum-1 Al27(n,alpha)Na24 foil
# Read in properties of Zirconium-2 Zr90(n,2n)Zr89 foil
# Read in properties of Zirconium-3 Zr90(n,2n)Zr89 foil
# Read in properties of Zirconium-9 Zr90(n,2n)Zr89 foil
# Read in properties of Zirconium-11 Zr90(n,2n)Zr89 foil
# Read in properties of Zirconium-10 Zr90(n,2n)Zr89 foil
# Read in properties of Zirconium-12 Zr90(n,2n)Zr89 foil
# Read in properties of Niobium-10 Nb93(n,2n)Nb92m foil
# Read in properties of Niobium-11 Nb93(n,2n)Nb92m foil
# Read in properties of Niobium-12 Nb93(n,2n)Nb92m foil
# Read in properties of Niobium-13 Nb93(n,2n)Nb92m foil
# Checking if measurement directory exists at ../../data/NaI/nGen_charac_NaI/DAQ...
# Measurement directory ../../data/NaI/nGen_charac_NaI/DAQ already exists. Skipping download and extraction.
# Processing Co60 Count 1...
# Found data file: Data_CH0@DT5790M_908_Co60_0_872uCi_19Mar2014_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Co60_0_872uCi_19Mar2014_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Co60_0_872uCi_19Mar2014_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Co60_0_872uCi_19Mar2014_count1/Co60_0_872uCi_19Mar2014_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Co60 Count 2...
# Found data file: Data_CH1@DT5790M_908_Co60_0_872uCi_19Mar2014_count2.CSV
# Found data file: Data_CH0@DT5790M_908_Co60_0_872uCi_19Mar2014_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Co60_0_872uCi_19Mar2014_count2/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Co60_0_872uCi_19Mar2014_count2/Co60_0_872uCi_19Mar2014_count2_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Cs137 Count 1...
# Found data file: Data_CH1@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1_2.CSV
# Found data file: Data_CH1@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1_2.CSV
# Found data file: Data_CH1@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Cs137_9_38uCi_29Sep2023_count1_1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Cs137_9_38uCi_29Sep2023_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Cs137_9_38uCi_29Sep2023_count1/Cs137_9_38uCi_29Sep2023_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Cs137 Count 2...
# Found data file: Data_CH1@DT5790M_908_Cs137_9_38uCi_29Sep2023_count2.CSV
# Found data file: Data_CH0@DT5790M_908_Cs137_9_38uCi_29Sep2023_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Cs137_9_38uCi_29Sep2023_count2/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Cs137_9_38uCi_29Sep2023_count2/Cs137_9_38uCi_29Sep2023_count2_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Na22 Count 1...
# Found data file: Data_CH0@DT5790M_908_Na22_9_98uCi_29Sep2023_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Na22_9_98uCi_29Sep2023_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Na22_9_98uCi_29Sep2023_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Na22_9_98uCi_29Sep2023_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Na22_9_98uCi_29Sep2023_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Na22_9_98uCi_29Sep2023_count1/Na22_9_98uCi_29Sep2023_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Na22 Count 2...
# Found data file: Data_CH1@DT5790M_908_Na22_9_98uCi_29Sep2023_count2.CSV
# Found data file: Data_CH0@DT5790M_908_Na22_9_98uCi_29Sep2023_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Na22_9_98uCi_29Sep2023_count2/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Na22_9_98uCi_29Sep2023_count2/Na22_9_98uCi_29Sep2023_count2_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Mn54 Count 1...
# Found data file: Data_CH1@DT5790M_908_Mn54_6_27uCi_2May2016_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Mn54_6_27uCi_2May2016_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Mn54_6_27uCi_2May2016_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Mn54_6_27uCi_2May2016_count1/Mn54_6_27uCi_2May2016_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Mn54 Count 2...
# Found data file: Data_CH0@DT5790M_908_Mn54_6_27uCi_2May2016_count2.CSV
# Found data file: Data_CH1@DT5790M_908_Mn54_6_27uCi_2May2016_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Mn54_6_27uCi_2May2016_count2/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Mn54_6_27uCi_2May2016_count2/Mn54_6_27uCi_2May2016_count2_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing background...
# Found data file: Data_CH1@DT5790M_908_Background_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Background_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Background_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Background_count1_1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Background_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Background_count1/Background_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Aluminum-1 Al27(n,alpha)Na24 Count 1...
# Found data file: Data_CH0@DT5790M_908_Aluminum1_long_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Aluminum1_long_count1_2.CSV
# Found data file: Data_CH1@DT5790M_908_Aluminum1_long_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Aluminum1_long_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Aluminum1_long_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Aluminum1_long_count1_2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Aluminum1_long_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Aluminum1_long_count1/Aluminum1_long_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-2 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH0@DT5790M_908_Zirconium2_90deg_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Zirconium2_90deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium2_90deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium2_90deg_count1/Zirconium2_90deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-3 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH1@DT5790M_908_Zirconium3_270deg_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Zirconium3_270deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium3_270deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium3_270deg_count1/Zirconium3_270deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-9 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH0@DT5790M_908_Zirconium9_120deg_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Zirconium9_120deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium9_120deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium9_120deg_count1/Zirconium9_120deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-11 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH0@DT5790M_908_Zirconium9_180deg_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Zirconium9_180deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium11_180deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium11_180deg_count1/Zirconium11_180deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-10 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH1@DT5790M_908_Zirconium10_150deg_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Zirconium10_150deg_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Zirconium10_150deg_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Zirconium10_150deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium10_150deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium10_150deg_count1/Zirconium10_150deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Zirconium-12 Zr90(n,2n)Zr89 Count 1...
# Found data file: Data_CH1@DT5790M_908_Zirconium12_under_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Zirconium12_under_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium12_under_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Zirconium12_under_count1/Zirconium12_under_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Niobium-10 Nb93(n,2n)Nb92m Count 1...
# Found data file: Data_CH0@DT5790M_908_Niobium10_60deg_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Niobium10_60deg_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Niobium10_60deg_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Niobium10_60deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium10_60deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium10_60deg_count1/Niobium10_60deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Niobium-11 Nb93(n,2n)Nb92m Count 1...
# Found data file: Data_CH1@DT5790M_908_Niobium11_150deg_count1.CSV
# Found data file: Data_CH0@DT5790M_908_Niobium11_150deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium11_150deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium11_150deg_count1/Niobium11_150deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Niobium-12 Nb93(n,2n)Nb92m Count 1...
# Found data file: Data_CH0@DT5790M_908_Niobium12_120deg_count2.CSV
# Found data file: Data_CH1@DT5790M_908_Niobium12_120deg_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium12_120deg_count2/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium12_120deg_count2/Niobium12_120deg_count2_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Processing Niobium-13 Nb93(n,2n)Nb92m Count 1...
# Found data file: Data_CH0@DT5790M_908_Niobium13_180deg_count1.CSV
# Found data file: Data_CH1@DT5790M_908_Niobium13_180deg_count1_1.CSV
# Found data file: Data_CH0@DT5790M_908_Niobium13_180deg_count1_1.CSV
# Found data file: Data_CH1@DT5790M_908_Niobium13_180deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium13_180deg_count1/run.info
# Looking for info.txt file at ../../data/NaI/nGen_charac_NaI/DAQ/Niobium13_180deg_count1/Niobium13_180deg_count1_info.txt
# Hello world from get_start_stop_time_from_info_txt!
# Found settings.xml file. Using energy bins from file: 4096
# Saving processed measurements to h5 file for future use...
#  ../../data NaI_activation_data.h5
# Saving measurements to ../../data/NaI_activation_data.h5...

# %% [markdown]
# ## Energy Calibration
#
# Using gamma check sources like Co-60 and Cs-137, the characteristic photon peaks from these sources are used to convert the digitizer channel bins into energy (keV) bins

# %%
peak_kwargs = {"Na22": {"start_index": 1000, "relative_height": 0.8, "relative_prominence": 0.8}}

# %%
import matplotlib.pyplot as plt
from libra_toolbox.neutron_detection.activation_foils import compass
import scipy
print("Scipy version:", scipy.__version__)
from scipy.signal import find_peaks

calibration_channels = {}
calibration_energies = {}
for name, measurement in check_source_measurements.items():
    fig, ax = plt.subplots(nrows=1, ncols=len(measurement.detectors))
    if not isinstance(ax, np.ndarray):
        ax = [ax]
    for d,detector in enumerate(measurement.detectors):
        if detector.channel_nb not in calibration_channels:
            calibration_channels[detector.channel_nb] = []
            calibration_energies[detector.channel_nb] = []
        hist, bin_edges = detector.get_energy_hist()
        ax[d].stairs(
            hist, 
            bin_edges,
            label=f"Ch {detector.channel_nb}",
        )

        # if peak_kwargs:
        #     print("Scipy peak kwargs:")
        #     for k, v in peak_kwargs.items():
        #         print(f"  {k}: {v}")
        #     scipy_peak_inds, _ = find_peaks(hist[peak_kwargs["start_index"]:],
        #                                     prominence=peak_kwargs['prominence'],
        #                                     height=peak_kwargs['height'],
        #                                     distance=peak_kwargs['distance'],
        #                                     width=peak_kwargs['width'] if 'width' in peak_kwargs else None)
        #     scipy_peak_inds += peak_kwargs["start_index"]
            # peaks_ind = measurement.get_peaks(hist, **peak_kwargs)
        if "Na22" in measurement.name and "Na22" in peak_kwargs:
            peaks_ind = measurement.get_peaks(hist, **peak_kwargs["Na22"])
        else:
            peaks_ind = measurement.get_peaks(hist)
        peaks = bin_edges[peaks_ind]

        # if peak_kwargs:
        #     ax[d].vlines(bin_edges[peak_kwargs["start_index"]], 0, 1.1 * np.max(hist), 
        #                 colors='g', linestyles='dashed',
        #                 alpha=0.8, linewidth=1.0,
        #                 label='Cutoff')
        #     ax[d].vlines(bin_edges[scipy_peak_inds], 0, 1.1 * np.max(hist),
        #                 colors='m', linestyles='dashed',
        #                 alpha=0.8, linewidth=1.0,
        #                 label='SciPy Peaks')

        ax[d].vlines(peaks, 0, 1.1 * np.max(hist), 
                    colors='r', linestyles='dashed',
                    alpha=0.8, linewidth=1.0,
                    label='Peaks')
        
        ax[d].legend()
        ax[d].set_yscale("linear")
        ax[d].set_ylim(top=1.1 * np.max(hist))
        ax[d].set_title(f"{measurement.name} - {detector.channel_nb}")
        ax[d].set_xlabel("Energy Channel")
        ax[d].set_ylabel("Counts")
        # ax[d].set_xlim(0, bin_edges[scipy_peak_inds[-1] + 10] * 1.5)

        if len(peaks) != len(measurement.check_source.nuclide.energy):
            print(f"Peaks found: {peaks}, expected: {measurement.check_source.nuclide.energy}")
            raise ValueError(
                f"SciPy find_peaks() found {len(peaks)} photon peaks, while {len(measurement.check_source.nuclide.energy)} were expected"
            )
        calibration_channels[detector.channel_nb] += list(peaks)
        calibration_energies[detector.channel_nb] += measurement.check_source.nuclide.energy

    fig.tight_layout()

for ch in calibration_channels.keys():
    inds = np.argsort(calibration_channels[ch])
    calibration_channels[ch] = np.array(calibration_channels[ch])[inds]
    calibration_energies[ch] = np.array(calibration_energies[ch])[inds]

plt.show()
# Out:
# Scipy version: 1.16.0
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values

# %%
calibration_channels = {}
calibration_energies = {}
for ch in [0,1]:
    calibration_channels[ch], calibration_energies[ch] = compass.get_calibration_data(check_source_measurements=check_source_measurements.values(),
                                                                                     background_measurement=background_meas,
                                                                                     channel_nb=ch,
                                                                                     peak_kwargs=peak_kwargs)
    print("Calibration channels:", calibration_channels[ch])
    print("Calibration energies:", calibration_energies[ch])
# Out:
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values
# Calibration channels: [ 874  876 1072 1088 1504 1510 1634 1634 1707 1710]
# Calibration energies: [ 661.657  661.657  834.848  834.848 1173.228 1173.228 1274.537 1274.537
#  1332.492 1332.492]
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values
# Calibration channels: [ 589  591  739  744 1018 1018 1108 1111 1156 1157]
# Calibration energies: [ 661.657  661.657  834.848  834.848 1173.228 1173.228 1274.537 1274.537
#  1332.492 1332.492]

# %%
calibration_coeffs = {}

for channel_nb in [0,1]:


    coeff = np.polyfit(calibration_channels[channel_nb], calibration_energies[channel_nb], 1)
    calibration_coeffs[channel_nb] = coeff

    xs = np.linspace(
        calibration_channels[channel_nb][0],
        calibration_channels[channel_nb][-1],
    )
    plt.plot(
        xs,
        np.polyval(coeff, xs),
        label=f"Ch {channel_nb} fit",
    )
    plt.scatter(
        calibration_channels[channel_nb],
        calibration_energies[channel_nb],
        label=f"Ch {channel_nb} data",
        alpha=0.5,
    )
plt.xlabel("Channel number")
plt.ylabel("Energy (keV)")
plt.legend()
plt.show()

# %% [markdown]
# ## Detector Efficiency
#
# Using these same check-sources, each with a known activity, an efficiency curve for each detector is calculated.
#
# Two types of efficiency curves are shown:
# 1. Exponent of sum of logarithms (used in https://doi.org/10.2172/1524045): $ y = \exp(\sum_{i=0}^n a_n \log(E)^i) $
#
# 2. Polynomial fit (3rd order): $ y = \sum_{i=0}^n a_n E^i $
#
# **Only the polynomal fit is currently implemented in libra-toolbox, so that is the curve that will be used to calculate the efficiency of the detectors at measuring the activity of the activation foil peaks.**

# %% [markdown]
# ## Bayesian Model with Preset Function

# %% [markdown]
# ## Why Find the Peak of the Posterior Probability Distribution?
#
# The **Maximum A Posteriori (MAP)** method finds the peak of the posterior probability distribution because **this peak represents the parameter values that are most consistent with both your data AND your prior knowledge**.
#
# ### The Intuitive Explanation
#
# Imagine you're trying to estimate the efficiency parameters for your detector. You have:
#
# 1. **Your measured data**: Efficiency measurements at different energies (with uncertainties)
# 2. **Your prior knowledge**: Physical intuition about what reasonable parameter values should be
#
# The posterior probability tells you: *"Given my prior beliefs and the data I just collected, how likely is each possible set of parameter values?"*
#
# - **High probability** = These parameter values make sense given both physics and data
# - **Low probability** = These parameter values either contradict the data or seem physically unreasonable
#
# **The peak is where these two sources of information agree most strongly.**
#
# ### Why Not Just Fit the Data Without Priors?
#
# Without priors (pure maximum likelihood), you might get:
# - Parameter values that fit the data perfectly but are physically unrealistic
# - Overfitting to noise in your measurements
# - Unstable results when you have limited data points
#
# ### Why Not Just Use Prior Knowledge Without Data?
#
# Without considering the data, you'd just be guessing based on theory - you wouldn't learn anything from your actual measurements!
#
# ### The MAP Sweet Spot
#
# The MAP estimate finds the **optimal balance** between:
# - **Fitting your data well** (high likelihood)
# - **Staying within reasonable bounds** (respecting priors)
#
# ### Real-World Example
#
# In your efficiency fitting:
# - Your **data** says: "At 600 keV, efficiency was 0.021 ± 0.0006"
# - Your **prior** says: "Based on physics, I expect a₀ ≈ -2, a₁ ≈ 0.5"
# - The **MAP** finds: "The parameters that best satisfy BOTH constraints simultaneously"
#
# ### What the Peak Tells You
#
# The peak represents the **most credible parameter values** - if you had to make your best single guess about the true parameters, this would be it.
#
# The **width of the peak** (which we estimate with the Hessian) tells you how confident you can be in this estimate:
# - **Narrow peak** = High confidence, well-constrained parameters
# - **Broad peak** = Lower confidence, parameters could vary more
#
# This is why MAP is so powerful for scientific applications - it gives you both the best estimate AND a measure of how reliable that estimate is!

# %%
def eff_curve_func(E, *a):
    exponent_term = 0
    for i,a_n in enumerate(a):
        exponent_term += a_n * (np.log(E) ** i)
    return np.exp(exponent_term)

# %% [markdown]
# ### The MAP Balancing Act
#
# The key insight is that **finding the peak of the posterior probability distribution gives you the parameter values that represent the best compromise between your prior knowledge and your data**.
#
# Here's why this matters specifically for your efficiency measurements:
#
# #### The Three Alternatives and Their Problems:
#
# 1. **Pure Data Fitting (Maximum Likelihood Only)**
#    - Problem: Might give physically unrealistic parameters
#    - Example: Could suggest efficiency increases with energy (violates physics)
#
# 2. **Pure Prior Knowledge (Ignore Data)**
#    - Problem: You learn nothing from your expensive measurements!
#    - Example: Just assume efficiency follows some textbook curve
#
# 3. **Arbitrary Weighting**
#    - Problem: How much should you trust data vs. prior knowledge?
#    - Example: "I'll trust the data 70% and my prior 30%" - but why those numbers?
#
# #### The MAP Solution:
#
# The MAP method **automatically finds the optimal balance** using probability theory. The peak occurs where:
#
# ```
# P(parameters | data, prior) ∝ P(data | parameters) × P(parameters)
#                                     ↑                    ↑
#                                Likelihood              Prior
# ```
#
# - If your **data is very precise** (small error bars), the likelihood dominates → MAP trusts data more
# - If your **data is noisy** (large error bars), the prior has more influence → MAP stays closer to physics intuition
# - If your **prior is very certain** (narrow distribution), it constrains the result more
# - If your **prior is vague** (wide distribution), the data drives the result
#
# #### In Your Specific Case:
#
# When you fit detector efficiency vs energy:
# - **Data says**: "Here are my measured efficiencies with their uncertainties"
# - **Prior says**: "Physics suggests a₀ should be around -2 (log-scale efficiency), a₁ should be positive (efficiency decreases with energy)"
# - **MAP finds**: The parameter values that best satisfy both simultaneously
#
# The peak represents the **most defensible scientific estimate** - it's the set of parameters you'd report in a paper because they're both consistent with your measurements AND physically reasonable.
#
# The beauty of MAP is that it does this balancing act **objectively** using probability theory, rather than requiring you to make subjective judgments about how much to weight different sources of information.

# %%
from scipy.optimize import curve_fit
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (
    ConstantKernel, Matern, RationalQuadratic, RBF
)

channels = []
efficiency_coeffs = {}

efficiency_dict = {}
efficiency_err_dict = {}
energy_dict = {}

measurement = list(check_source_measurements.values())[0]
search_width = 150

for detector in measurement.detectors:
    channels.append(detector.channel_nb)

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
for i,ch in enumerate(channels):
    background_detector = background_meas.get_detector(ch)
    energies = []
    efficiencies = []
    eff_errs = []
    for name, measurement in check_source_measurements.items():
        check_source_detector = measurement.get_detector(ch)
        hist, bin_edges = check_source_detector.get_energy_hist_background_substract(background_detector)
        calibrated_bin_edges = np.polyval(calibration_coeffs[ch], bin_edges)
        fig_1, ax_1 = plt.subplots()
        ax_1.stairs(hist, calibrated_bin_edges)
        ax_1.set_title(f"{name} - Ch {ch}")
        ax_1.set_xlabel("Energy (keV)")
        ax_1.set_ylabel("Counts")

        print("measurement._uncalibrated_measured_energies:", measurement._uncalibrated_measured_energies[ch])
        peak_energies = measurement.get_calibrated_measured_energies(ch,
                                                                     calibration_coeffs=calibration_coeffs[ch])
        ax_1.set_xlim(peak_energies[0] * 0.8, peak_energies[-1] * 1.2)
        ax_1.set_yscale('log')
        
        efficiency, eff_err = measurement.compute_detection_efficiency(
            background_measurement=background_meas,
            calibration_coeffs=calibration_coeffs[ch],
            channel_nb=ch,
            search_width=search_width,
            compute_error=True,
            threshold_overlap=200,
            ax=ax_1
        )
        print(f"{name} Ch {ch}: Efficiency = {efficiency} +/- {eff_err}")

        energies += measurement.check_source.nuclide.energy
        efficiencies += list(efficiency)
        eff_errs += list(eff_err)
        ax[i].errorbar(
            measurement.check_source.nuclide.energy,
            efficiency * 100,
            yerr=eff_err * 100,
            label=name,
            fmt="o",
        )

    # Sort energies and efficiencies for fitting
    sorted_indices = np.argsort(energies)
    energies = np.array(energies)[sorted_indices]
    efficiencies = np.array(efficiencies)[sorted_indices]
    eff_errs = np.array(eff_errs)[sorted_indices]

    energy_dict[ch] = energies
    efficiency_dict[ch] = efficiencies
    efficiency_err_dict[ch] = eff_errs
    
    print(f"Ch {ch} \n\t Energies: {energies}, \n\t Efficiencies: {efficiencies}")

    # Fit the efficiency curve

    poly_coeff = np.polyfit(energies, efficiencies, 3)
    efficiency_coeffs[ch] = poly_coeff
    xs = np.linspace(
        energies[0],
        energies[-1],
        100,
    )

    ax[i].plot(
        xs,
        np.polyval(poly_coeff, xs) * 100,
        label="Polyfit efficiency curve",
    )
    ax[i].set_xlabel("Energy (keV)")
    ax[i].set_ylabel("Detection efficiency (%)")
    ax[i].set_title(f"Channel {ch}")
    ax[i].legend()
    # plt.ylim(bottom=0)

plt.show()
# Out:
# measurement._uncalibrated_measured_energies: [np.int64(1504), np.int64(1710)]
# [1170.15081191 1335.40918265]
# Plotting initial guess...
# Plotting fitted curve...
# Co60 Count 1 Ch 0: Efficiency = [0.01045122 0.00978282] +/- [6.70277191e-05 6.48059314e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1510), np.int64(1707)]
# [1174.96416251 1333.00250735]
# Plotting initial guess...
# Plotting fitted curve...
# Co60 Count 2 Ch 0: Efficiency = [0.01085297 0.01055064] +/- [5.05143488e-05 4.97727378e-05]
# measurement._uncalibrated_measured_energies: [np.int64(876)]
# [666.35344868]
# Plotting initial guess...
# Plotting fitted curve...
# Cs137 Count 1 Ch 0: Efficiency = [0.01824269] +/- [1.83461993e-05]
# measurement._uncalibrated_measured_energies: [np.int64(874)]
# [664.74899848]
# Plotting initial guess...
# Plotting fitted curve...
# Cs137 Count 2 Ch 0: Efficiency = [0.01895069] +/- [4.1223597e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1634)]
# [1274.440075]
# Plotting initial guess...
# Plotting fitted curve...
# Na22 Count 1 Ch 0: Efficiency = [0.01066464] +/- [1.83129435e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1634)]
# [1274.440075]
# Plotting initial guess...
# Plotting fitted curve...
# Na22 Count 2 Ch 0: Efficiency = [0.01086984] +/- [2.62946345e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1088)]
# [836.42517002]
# Plotting initial guess...
# Plotting fitted curve...
# Mn54 Count 1 Ch 0: Efficiency = [0.01513672] +/- [0.00016179]
# measurement._uncalibrated_measured_energies: [np.int64(1072)]
# [823.58956841]
# Plotting initial guess...
# Plotting fitted curve...
# Mn54 Count 2 Ch 0: Efficiency = [0.01624498] +/- [0.00018789]
# Ch 0
# 	 Energies: [ 661.657  661.657  834.848  834.848 1173.228 1173.228 1274.537 1274.537
#  1332.492 1332.492],
# 	 Efficiencies: [0.01895069 0.01824269 0.01624498 0.01513672 0.01045122 0.01085297
#  0.01066464 0.01086984 0.00978282 0.01055064]
# measurement._uncalibrated_measured_energies: [np.int64(1018), np.int64(1157)]
# [1168.1766099  1333.43019446]
# Plotting initial guess...
# Plotting fitted curve...
# Co60 Count 1 Ch 1: Efficiency = [0.01541515 0.01383925] +/- [8.14655425e-05 7.71379528e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1018), np.int64(1156)]
# [1168.1766099  1332.24131975]
# Plotting initial guess...
# Plotting fitted curve...
# Co60 Count 2 Ch 1: Efficiency = [0.01455721 0.0122945 ] +/- [5.84497499e-05 5.36798087e-05]
# measurement._uncalibrated_measured_energies: [np.int64(589)]
# [658.14935968]
# Plotting initial guess...
# Plotting fitted curve...
# Cs137 Count 1 Ch 1: Efficiency = [0.02863032] +/- [2.29846677e-05]
# measurement._uncalibrated_measured_energies: [np.int64(591)]
# [660.5271091]
# Plotting initial guess...
# Plotting fitted curve...
# Cs137 Count 2 Ch 1: Efficiency = [0.02761464] +/- [4.97233727e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1111)]
# [1278.74195784]
# Plotting initial guess...
# Plotting fitted curve...
# Na22 Count 1 Ch 1: Efficiency = [0.01531813] +/- [2.19513284e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1108)]
# [1275.17533372]
# Plotting initial guess...
# Plotting fitted curve...
# Na22 Count 2 Ch 1: Efficiency = [0.01503725] +/- [3.09105458e-05]
# measurement._uncalibrated_measured_energies: [np.int64(739)]
# [836.48056605]
# Plotting initial guess...
# Plotting fitted curve...
# Mn54 Count 1 Ch 1: Efficiency = [0.02285368] +/- [0.00019874]
# measurement._uncalibrated_measured_energies: [np.int64(744)]
# [842.4249396]
# Plotting initial guess...
# Plotting fitted curve...
# Mn54 Count 2 Ch 1: Efficiency = [0.02237368] +/- [0.000221]
# Ch 1
# 	 Energies: [ 661.657  661.657  834.848  834.848 1173.228 1173.228 1274.537 1274.537
#  1332.492 1332.492],
# 	 Efficiencies: [0.02761464 0.02863032 0.02237368 0.02285368 0.01541515 0.01455721
#  0.01531813 0.01503725 0.01383925 0.0122945 ]

# %%
# Simplified Bayesian-style fitting without PyMC compilation issues
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize, differential_evolution
from scipy.stats import multivariate_normal
import warnings
warnings.filterwarnings('ignore')

def negative_log_posterior(params, energies, efficiencies, eff_errs):
    """Negative log posterior for optimization"""
    a0, a1, a2, a3 = params
    
    # Priors (log normal distributions)
    log_prior = 0
    log_prior += -0.5 * ((a0 - (-2.0))/2.0)**2  # Prior centered at -2
    log_prior += -0.5 * ((a1 - 0.5)/1.0)**2     # Prior centered at 0.5  
    log_prior += -0.5 * ((a2 - 0.0)/0.5)**2     # Prior centered at 0
    log_prior += -0.5 * ((a3 - 0.0)/0.1)**2     # Prior centered at 0
    
    # Likelihood
    try:
        model_pred = eff_curve_func(energies, a0, a1, a2, a3)
        if np.any(np.isnan(model_pred)) or np.any(np.isinf(model_pred)) or np.any(model_pred <= 0):
            return 1e10
        residuals = (efficiencies - model_pred) / eff_errs
        log_likelihood = -0.5 * np.sum(residuals**2)
    except:
        return 1e10
    
    return -(log_prior + log_likelihood)

map_results = {}
# Process each channel
for ch in energy_dict.keys():
    print(f"\nProcessing Channel {ch}")
    
    energies = energy_dict[ch]
    efficiencies = efficiency_dict[ch]
    eff_errs = efficiency_err_dict[ch]
    
    # Find MAP (Maximum A Posteriori) estimate
    bounds = [(-10, 5), (-2, 3), (-1, 1), (-0.5, 0.5)]  # Reasonable bounds
    
    # Use differential evolution for global optimization
    result = differential_evolution(
        negative_log_posterior, 
        bounds, 
        args=(energies, efficiencies, eff_errs),
        seed=42,
        maxiter=1000,
        tol=1e-6
    )
    
    if result.success:
        map_params = result.x
        print(f"MAP estimate: a0={map_params[0]:.3f}, a1={map_params[1]:.3f}, a2={map_params[2]:.3f}, a3={map_params[3]:.3f}")
        
        # Estimate uncertainty using Hessian approximation
        from scipy.optimize import approx_fprime
        
        def neg_log_post_wrapper(params):
            return negative_log_posterior(params, energies, efficiencies, eff_errs)
        
        # Approximate the Hessian at MAP
        eps = 1e-5
        hess_diag = []
        for i in range(4):
            params_plus = map_params.copy()
            params_minus = map_params.copy()
            params_plus[i] += eps
            params_minus[i] -= eps
            
            second_deriv = (neg_log_post_wrapper(params_plus) - 
                          2*neg_log_post_wrapper(map_params) + 
                          neg_log_post_wrapper(params_minus)) / eps**2
            hess_diag.append(max(second_deriv, 1e-6))  # Ensure positive
        
        # Parameter uncertainties (diagonal approximation)
        param_stds = 1.0 / np.sqrt(np.array(hess_diag))
        
        print(f"Parameter uncertainties: ±{param_stds[0]:.3f}, ±{param_stds[1]:.3f}, ±{param_stds[2]:.5f}, ±{param_stds[3]:.5f}")
        
        # Store MAP results for later use
        map_results[ch] = {
            'params': map_params,
            'uncertainties': param_stds,
            'energy_range': (energies.min(), energies.max())
        }
        
        # Generate samples from approximate posterior (multivariate normal)
        cov_matrix = np.diag(param_stds**2)
        n_samples = 1000
        posterior_samples = multivariate_normal.rvs(
            mean=map_params, 
            cov=cov_matrix, 
            size=n_samples,
            random_state=42
        )
        
        # Plot results
        plt.figure(figsize=(10, 5))

        done_511 = 0
        done_1275 = 0
        done_662 = 0
        done_835 = 0
        done_1173 = 0
        done_1332 = 0
        # Plot data
        for i,data_i in enumerate(zip(energies, efficiencies, eff_errs)):
            energy, efficiency, eff_err = data_i
            if 500 < energy < 520:
                source_label = 'Na-22'
                source_color = 'tab:blue'
            elif 600 < energy < 700:
                source_label = 'Cs-137'
                source_color = 'purple'
            elif 800 < energy < 900:
                source_label = 'Mn-54'
                source_color = 'gray'
            elif 1100 < energy < 1200:
                source_label = 'Co-60'
                source_color = 'green'
            elif 1200 < energy < 1300:
                source_label = "Na-22"
                source_color = 'tab:blue'
            elif 1300 < energy < 1400:
                source_label = 'Co-60'
                source_color = 'green'
            else:
                source_label = 'Other'
                source_color = 'gray'
            if i==0:
                plot_label = "Measured"
            else:
                plot_label = None
            plt.errorbar(energy, efficiency, yerr=eff_err, fmt='o', label=plot_label, 
                         color=source_color, capsize=3, markersize=6)
            if np.mod(i,2)==0:
                plt.text(energy, efficiency + 0.002, source_label, color=source_color, 
                        fontsize=10, ha='center')
            

        # plt.errorbar(energies, efficiencies, yerr=eff_errs, fmt='o', 
        #             label='Data', capsize=3, markersize=6)
        
        # Plot MAP fit
        xs = np.linspace(energies.min(), energies.max(), 200)
        map_curve = eff_curve_func(xs, *map_params)
        plt.plot(xs, map_curve, 'r-', linewidth=2, label='MAP fit')
        
        # Plot uncertainty band using posterior samples
        curves = []
        for i in range(0, min(200, len(posterior_samples)), 5):
            try:
                curve = eff_curve_func(xs, *posterior_samples[i])
                if np.all(np.isfinite(curve)) and np.all(curve > 0):
                    curves.append(curve)
                    if len(curves) <= 20:  # Only plot first 20 for visibility
                        plt.plot(xs, curve, 'gray', alpha=0.1, linewidth=0.5)
            except:
                continue
        
        # Calculate credible interval
        if curves:
            curves = np.array(curves)
            lower = np.percentile(curves, 2.5, axis=0)
            upper = np.percentile(curves, 97.5, axis=0)
            plt.fill_between(xs, lower, upper, alpha=0.3, color='red', 
                           label='95% Credible Interval')
        
        plt.xlabel('Energy (keV)', fontsize=12)
        plt.ylabel('Efficiency', fontsize=12)
        plt.title(f'MAP Efficiency Fit - Channel {ch}', fontsize=16)
        plt.legend()
        plt.grid(True, alpha=0.3)
        # plt.ylim(0.005, np.max(efficiencies)*1.2)
        plt.savefig(f'efficiency_fit_channel_{ch}.png', dpi=300)
        plt.show()
        
        # Summary statistics
        print(f"\nPosterior Summary for Channel {ch}:")
        param_names = ['a0', 'a1', 'a2', 'a3']
        print(f"{'Parameter':<10} {'Mean':<10} {'Std':<10} {'2.5%':<10} {'97.5%':<10}")
        print("-" * 50)
        for i, name in enumerate(param_names):
            samples_i = posterior_samples[:, i]
            mean_val = np.mean(samples_i)
            std_val = np.std(samples_i)
            q025 = np.percentile(samples_i, 2.5)
            q975 = np.percentile(samples_i, 97.5)
            print(f"{name:<10} {mean_val:<10.3f} {std_val:<10.3f} {q025:<10.3f} {q975:<10.3f}")
    
    else:
        print(f"Optimization failed for channel {ch}")
        print("Falling back to simple curve_fit...")
        
        # Fallback to scipy curve_fit
        from scipy.optimize import curve_fit
        try:
            popt, pcov = curve_fit(eff_curve_func, energies, efficiencies, 
                                 sigma=eff_errs, p0=[-2, 0.5, 0, 0])
            param_errs = np.sqrt(np.diag(pcov))
            
            plt.figure(figsize=(10, 6))
            plt.errorbar(energies, efficiencies, yerr=eff_errs, fmt='o', 
                        label='Data', capsize=3)
            xs = np.linspace(energies.min(), energies.max(), 200)
            plt.plot(xs, eff_curve_func(xs, *popt), 'r-', linewidth=2, 
                    label='Curve fit')
            plt.xlabel('Energy (keV)')
            plt.ylabel('Efficiency')
            plt.title(f'Fallback Curve Fit - Channel {ch}')
            plt.legend()
            plt.show()
            
            print(f"Fitted parameters: a0={popt[0]:.3f}±{param_errs[0]:.3f}, "
                  f"a1={popt[1]:.3f}±{param_errs[1]:.3f}, "
                  f"a2={popt[2]:.3f}±{param_errs[2]:.3f}, "
                  f"a3={popt[3]:.3f}±{param_errs[3]:.3f}")
        except Exception as e:
            print(f"Even curve_fit failed: {e}")

print("\nBayesian-style fitting complete!")
# Out:
# Processing Channel 0
# MAP estimate: a0=1.451, a1=2.148, a2=-0.879, a3=0.064
# Parameter uncertainties: ±0.001, ±0.000, ±0.00002, ±0.00000
# Posterior Summary for Channel 0:
# Parameter  Mean       Std        2.5%       97.5%
# --------------------------------------------------
# a0         1.451      0.001      1.449      1.452
# a1         2.148      0.000      2.148      2.149
# a2         -0.879     0.000      -0.879     -0.879
# a3         0.064      0.000      0.064      0.065
#
# Processing Channel 1
# MAP estimate: a0=0.091, a1=1.207, a2=-0.465, a3=0.030
# Parameter uncertainties: ±0.001, ±0.000, ±0.00001, ±0.00000
# Posterior Summary for Channel 1:
# Parameter  Mean       Std        2.5%       97.5%
# --------------------------------------------------
# a0         0.091      0.001      0.090      0.092
# a1         1.207      0.000      1.207      1.208
# a2         -0.465     0.000      -0.465     -0.465
# a3         0.030      0.000      0.030      0.030
#
# Bayesian-style fitting complete!

# %%
# Function to calculate efficiency and uncertainty at arbitrary energies
def calculate_efficiency_at_energy(energy, channel, method='propagation'):
    """
    Calculate efficiency and 1-sigma uncertainty at a given energy using MAP results
    
    Parameters:
    -----------
    energy : float or array
        Energy value(s) in keV where you want to calculate efficiency
    channel : int 
        Channel number (4 or 5)
    method : str
        'propagation' for analytical uncertainty propagation
        'sampling' for Monte Carlo sampling approach
        
    Returns:
    --------
    efficiency : float or array
        Predicted efficiency value(s)
    uncertainty : float or array  
        1-sigma uncertainty in efficiency
    """
    
    # Check if we have MAP results for this channel
    if channel not in map_results:
        raise ValueError(f"No MAP results available for channel {channel}. Run the Bayesian fitting first.")
    
    map_params = map_results[channel]['params']
    param_stds = map_results[channel]['uncertainties']
    
    # Convert energy to array for consistent handling
    energy = np.atleast_1d(energy)
    
    # Calculate efficiency using MAP parameters
    efficiency = eff_curve_func(energy, *map_params)
    
    if method == 'propagation':
        # Analytical uncertainty propagation using partial derivatives
        # For f(E) = exp(a0 + a1*ln(E) + a2*ln(E)^2 + a3*ln(E)^3)
        # df/da_i = f(E) * ln(E)^i
        
        log_E = np.log(energy)
        
        # Partial derivatives
        df_da0 = efficiency  # df/da0 = f(E)
        df_da1 = efficiency * log_E  # df/da1 = f(E) * ln(E)
        df_da2 = efficiency * log_E**2  # df/da2 = f(E) * ln(E)^2  
        df_da3 = efficiency * log_E**3  # df/da3 = f(E) * ln(E)^3
        
        # Uncertainty propagation: sigma_f^2 = sum((df/da_i)^2 * sigma_a_i^2)
        uncertainty_squared = (
            (df_da0 * param_stds[0])**2 + 
            (df_da1 * param_stds[1])**2 + 
            (df_da2 * param_stds[2])**2 + 
            (df_da3 * param_stds[3])**2
        )
        uncertainty = np.sqrt(uncertainty_squared)
        
    elif method == 'sampling':
        # Monte Carlo sampling approach
        n_samples = 1000
        cov_matrix = np.diag(param_stds**2)
        
        # Generate parameter samples
        param_samples = np.random.multivariate_normal(
            map_params, cov_matrix, size=n_samples
        )
        
        # Calculate efficiency for each parameter sample
        efficiency_samples = []
        for params in param_samples:
            try:
                eff_sample = eff_curve_func(energy, *params)
                if np.all(np.isfinite(eff_sample)) and np.all(eff_sample > 0):
                    efficiency_samples.append(eff_sample)
            except:
                continue
                
        if efficiency_samples:
            efficiency_samples = np.array(efficiency_samples)
            # Use the mean and std of samples
            efficiency = np.mean(efficiency_samples, axis=0)
            uncertainty = np.std(efficiency_samples, axis=0)
        else:
            # Fallback to propagation method
            return calculate_efficiency_at_energy(energy, channel, method='propagation')
    
    # Return scalar if input was scalar
    if len(energy) == 1:
        return float(efficiency[0]), float(uncertainty[0])
    else:
        return efficiency, uncertainty


print("Efficiency calculation function defined. Run the Bayesian fitting to populate map_results.")
# Out:
# Efficiency calculation function defined. Run the Bayesian fitting to populate map_results.

# %% [markdown]
# ## Uncertainty Quantification: Propagation vs. Sampling
#
# The `calculate_efficiency_at_energy()` function offers two methods for estimating uncertainties. Here's a detailed comparison:
#
# ### Method 1: Analytical Error Propagation ('propagation')
#
# **How it works:**
# - Uses partial derivatives to compute how uncertainties in parameters translate to uncertainties in predictions
# - Formula: `σ_f² = Σ(∂f/∂a_i)² × σ_a_i²`
# - For our efficiency function: `f(E) = exp(a₀ + a₁ln(E) + a₂ln²(E) + a₃ln³(E))`
#
# **Pros:**
# - **Fast**: Analytical calculation, no Monte Carlo sampling needed
# - **Exact**: Gives the mathematically correct uncertainty (for linear approximation)
# - **Deterministic**: Always gives the same result
# - **Memory efficient**: No need to store thousands of samples
# - **Good for real-time applications**: Instant results
#
# **Cons:**
# - **Linear approximation**: Only accurate when the function is approximately linear near the MAP estimate
# - **Assumes Gaussian uncertainties**: May underestimate uncertainties if parameter distributions are non-Gaussian
# - **No correlation information**: Our implementation assumes parameters are uncorrelated
# - **Can fail for highly nonlinear functions**: May give poor estimates if efficiency function has strong curvature
#
# **Best for:** Most routine calculations, when you need fast results, when parameter uncertainties are small relative to the function's curvature.
#
# ### Method 2: Monte Carlo Sampling ('sampling')
#
# **How it works:**
# - Generates many random parameter sets from the posterior distribution
# - Calculates efficiency for each parameter set
# - Uses the standard deviation of these predictions as the uncertainty estimate
#
# **Pros:**
# - **Handles nonlinearity**: Captures the true uncertainty even for highly nonlinear functions
# - **No mathematical approximations**: Directly samples from the posterior
# - **Captures asymmetric uncertainties**: Can detect if uncertainty is larger in one direction
# - **Can include correlations**: Easy to extend to include parameter correlations
# - **Robust**: Works for any function, no matter how complex
#
# **Cons:**
# - **Slower**: Requires generating and evaluating many samples (typically 1000+)
# - **Stochastic**: Results vary slightly between runs due to random sampling
# - **Memory intensive**: Must store parameter samples
# - **Assumes correct posterior approximation**: Only as good as your parameter uncertainty estimates
#
# **Best for:** When you suspect strong nonlinearities, want to capture asymmetric uncertainties, or need the most robust uncertainty estimate.
#
# ### When to Use Which Method?
#
# **Use Propagation when:**
# - You need fast, routine calculations
# - Parameter uncertainties are small (< 10% of parameter values)
# - The efficiency function is reasonably smooth and linear locally
# - You're doing many repeated calculations
#
# **Use Sampling when:**
# - You want the most robust uncertainty estimate
# - You suspect the efficiency function has strong curvature
# - Parameter uncertainties are large
# - You're doing a final, high-precision analysis
# - You want to check if propagation results are reliable
#
# ### For Your Efficiency Curves:
#
# In your case, the efficiency function `exp(a₀ + a₁ln(E) + ...)` is moderately nonlinear, but your MAP parameter uncertainties are quite small (σ ~ 0.01 for most parameters). This suggests:
#
# - **Propagation should be quite accurate** for most purposes
# - **Sampling provides a good cross-check** to verify propagation results
# - **Both methods should give similar results** if the linear approximation is valid
#
# ### Quick Comparison Test:
#
# You can easily compare both methods as shown below.  If the difference is < 5%, propagation is likely sufficient. If > 20%, the nonlinearity is significant and sampling is more trustworthy.

# %%
# Compare methods for a specific energy
energy = 900  # keV
eff_prop, unc_prop = calculate_efficiency_at_energy(energy, 1, method='propagation')
eff_samp, unc_samp = calculate_efficiency_at_energy(energy, 1, method='sampling')

print(f"Propagation: {eff_prop:.6f} ± {unc_prop:.6f}")
print(f"Sampling:    {eff_samp:.6f} ± {unc_samp:.6f}")
print(f"Difference:  {abs(unc_prop - unc_samp)/unc_prop*100:.1f}%")
# Out:
# Propagation: 0.020640 ± 0.000025
# Sampling:    0.020641 ± 0.000024
# Difference:  2.4%

# %%
# Practical comparison of propagation vs. sampling methods
if map_results:  # Only run if we have MAP results
    print("=== COMPARISON: Propagation vs. Sampling Methods ===\n")
    
    # Test energies spanning the fitted range
    test_energies = [600, 750, 900, 1050, 1200]
    
    for ch in map_results.keys():
        print(f"Channel {ch}:")
        print(f"{'Energy (keV)':<12} {'Method':<12} {'Efficiency':<12} {'Uncertainty':<12} {'Rel. Unc. (%)':<12}")
        print("-" * 65)
        
        for energy in test_energies:
            energy_range = map_results[ch]['energy_range']
            if energy_range[0] <= energy <= energy_range[1]:
                
                # Propagation method
                eff_prop, unc_prop = calculate_efficiency_at_energy(energy, ch, method='propagation')
                rel_unc_prop = unc_prop / eff_prop * 100
                
                # Sampling method
                eff_samp, unc_samp = calculate_efficiency_at_energy(energy, ch, method='sampling')
                rel_unc_samp = unc_samp / eff_samp * 100
                
                # Display results
                print(f"{energy:<12.0f} {'Propagation':<12} {eff_prop:<12.6f} {unc_prop:<12.6f} {rel_unc_prop:<12.1f}")
                print(f"{'':<12} {'Sampling':<12} {eff_samp:<12.6f} {unc_samp:<12.6f} {rel_unc_samp:<12.1f}")
                
                # Calculate difference
                unc_diff_pct = abs(unc_prop - unc_samp) / unc_prop * 100
                eff_diff_pct = abs(eff_prop - eff_samp) / eff_prop * 100
                
                print(f"{'':<12} {'Difference':<12} {eff_diff_pct:<11.3f}% {unc_diff_pct:<11.3f}%")
                print()
        
        print()
    
    
    # Summary assessment
    print("=== ASSESSMENT ===")
    print("If the uncertainty bands largely overlap and differences are < 5%:")
    print("→ Propagation method is sufficiently accurate")
    print("\nIf differences are 5-20%:")
    print("→ Moderate nonlinearity present, consider sampling for important calculations")
    print("\nIf differences are > 20%:")
    print("→ Strong nonlinearity, use sampling method for reliable uncertainties")
    
else:
    print("No MAP results available. Please run the Bayesian fitting first.")
# Out:
# === COMPARISON: Propagation vs. Sampling Methods ===
#
# Channel 0:
# Energy (keV) Method       Efficiency   Uncertainty  Rel. Unc. (%)
# -----------------------------------------------------------------
# 750          Propagation  0.016086     0.000023     0.1
#              Sampling     0.016086     0.000023     0.1
#              Difference   0.003      % 1.297      %
#
# 900          Propagation  0.013572     0.000020     0.1
#              Sampling     0.013571     0.000020     0.2
#              Difference   0.001      % 1.720      %
#
# 1050         Propagation  0.012023     0.000018     0.2
#              Sampling     0.012023     0.000018     0.2
#              Difference   0.004      % 1.643      %
#
# 1200         Propagation  0.011021     0.000017     0.2
#              Sampling     0.011021     0.000017     0.2
#              Difference   0.002      % 2.864      %
#
#
# Channel 1:
# Energy (keV) Method       Efficiency   Uncertainty  Rel. Unc. (%)
# -----------------------------------------------------------------
# 750          Propagation  0.024892     0.000029     0.1
#              Sampling     0.024892     0.000029     0.1
#              Difference   0.000      % 1.378      %
#
# 900          Propagation  0.020640     0.000025     0.1
#              Sampling     0.020641     0.000026     0.1
#              Difference   0.004      % 2.388      %
#
# 1050         Propagation  0.017745     0.000022     0.1
#              Sampling     0.017746     0.000022     0.1
#              Difference   0.007      % 1.990      %
#
# 1200         Propagation  0.015659     0.000020     0.1
#              Sampling     0.015660     0.000020     0.1
#              Difference   0.008      % 0.391      %
#
#
# === ASSESSMENT ===
# If the uncertainty bands largely overlap and differences are < 5%:
# → Propagation method is sufficiently accurate
#
# If differences are 5-20%:
# → Moderate nonlinearity present, consider sampling for important calculations
#
# If differences are > 20%:
# → Strong nonlinearity, use sampling method for reliable uncertainties

# %%
# Example: Calculate efficiency at specific energies
# (Run this after the Bayesian fitting above)

if map_results:  # Only run if we have MAP results
    print("Examples of calculating efficiency at arbitrary energies:\n")
    
    for ch in map_results.keys():
        energy_range = map_results[ch]['energy_range']
        print(f"Channel {ch} (valid range: {energy_range[0]:.0f} - {energy_range[1]:.0f} keV)")
        
        # Example energies within the fitted range
        test_energies = [600, 750, 900, 1000, 1200]
        
        for energy in test_energies:
            if energy_range[0] <= energy <= energy_range[1]:  # Check if within fitted range
                eff, eff_err = calculate_efficiency_at_energy(energy, ch, method='propagation')
                print(f"  At {energy} keV: efficiency = {eff:.6f} ± {eff_err:.6f} ({eff_err/eff*100:.1f}%)")
        
        print()
    
    # Example: Calculate efficiency curve with uncertainties
    print("Plotting efficiency curves with uncertainty bands:")
    
    fig, axes = plt.subplots(1, len(map_results), figsize=(12, 5))
    if len(map_results) == 1:
        axes = [axes]
    
    for i, ch in enumerate(map_results.keys()):
        energy_range = map_results[ch]['energy_range']
        
        # Create fine energy grid
        energy_grid = np.linspace(energy_range[0], energy_range[1], 100)
        
        # Calculate efficiencies and uncertainties
        eff_pred, eff_unc = calculate_efficiency_at_energy(energy_grid, ch, method='propagation')
        
        # Plot original data
        energies = energy_dict[ch]
        efficiencies = efficiency_dict[ch]
        eff_errs = efficiency_err_dict[ch]
        
        axes[i].errorbar(energies, efficiencies, yerr=eff_errs, fmt='o', 
                        label='Data', capsize=3, markersize=6)
        
        # Plot MAP prediction with uncertainty band
        axes[i].plot(energy_grid, eff_pred, 'r-', linewidth=2, label='MAP prediction')
        axes[i].fill_between(energy_grid, 
                            eff_pred - eff_unc, 
                            eff_pred + eff_unc,
                            alpha=0.3, color='red', label='±1σ uncertainty')
        
        axes[i].set_xlabel('Energy (keV)')
        axes[i].set_ylabel('Efficiency')
        axes[i].set_title(f'Channel {ch} - Efficiency Prediction')
        axes[i].legend()
        axes[i].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
else:
    print("No MAP results found. Please run the Bayesian fitting cell first.")
# Out:
# Examples of calculating efficiency at arbitrary energies:
#
# Channel 0 (valid range: 662 - 1332 keV)
#   At 750 keV: efficiency = 0.016086 ± 0.000023 (0.1%)
#   At 900 keV: efficiency = 0.013572 ± 0.000020 (0.1%)
#   At 1000 keV: efficiency = 0.012464 ± 0.000019 (0.2%)
#   At 1200 keV: efficiency = 0.011021 ± 0.000017 (0.2%)
#
# Channel 1 (valid range: 662 - 1332 keV)
#   At 750 keV: efficiency = 0.024892 ± 0.000029 (0.1%)
#   At 900 keV: efficiency = 0.020640 ± 0.000025 (0.1%)
#   At 1000 keV: efficiency = 0.018600 ± 0.000023 (0.1%)
#   At 1200 keV: efficiency = 0.015659 ± 0.000020 (0.1%)
#
# Plotting efficiency curves with uncertainty bands:

# %% [markdown]
# ## Calculating average neutron rate from activation foils
#
# First, the irradiation schedule and the foil information is collected.

# %%
for name, foil_dict in foil_measurements.items():
    print(f"Foil: {name}")
    print(foil_dict)
    for meas_name, measurement in foil_dict["measurements"].items():
        print(f"  Measurement: {meas_name}")
        for det in measurement.detectors:
            # hist, bin_edges = det.get_energy_hist_background_substract(background_meas.get_detector(det.channel_nb))
            # calibrated_bin_edges = np.polyval(calibration_coeffs[det.channel_nb], bin_edges)
            # plt.figure()
            # plt.stairs(hist, calibrated_bin_edges)
            # plt.title(f"{name} - {meas_name} - Ch {det.channel_nb}")
            # plt.xlabel("Energy (keV)")
            # plt.ylabel("Counts")
            # # plt.yscale('log')
            # plt.show()
            compass.plot_histogram_with_peak_fit(det,
                                                  calibration_coeffs=calibration_coeffs[det.channel_nb],
                                                  background_detector=background_meas.get_detector(det.channel_nb),
                                                  peak_energies=foil_dict["foil"].reaction.product.energy,
                                                  search_width=search_width,
                                                  threshold_overlap=200,
                                                  ax=None,
                                                  plot_peak_area=True,
            )
# Out:
# Foil: Aluminum-1 Al27(n,alpha)Na24
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Aluminum1_long_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Al27', energy=None, intensity=None, half_life=None, atomic_mass=26.9815, abundance=1.0), product=Nuclide(name='Na24', energy=[1368.63], intensity=[0.9994], half_life=53841.6, atomic_mass=23.99096, abundance=1.0), cross_section=np.float64(1.212352e-25), type='(n,alpha)'), mass=1.1022, name='Aluminum-1 Al27(n,alpha)Na24', density=2.7, thickness=0.20574), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ede6a50>}}
#   Measurement: 1
# Foil: Zirconium-2 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium2_90deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.6794, name='Zirconium-2 Zr90(n,2n)Zr89', density=6.52, thickness=0.0762), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ecece10>}}
#   Measurement: 1
# Foil: Zirconium-3 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium3_270deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.4498, name='Zirconium-3 Zr90(n,2n)Zr89', density=6.52, thickness=0.050800000000000005), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ececcd0>}}
#   Measurement: 1
# Foil: Zirconium-9 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium9_120deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.4462, name='Zirconium-9 Zr90(n,2n)Zr89', density=6.52, thickness=0.050800000000000005), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ec12190>}}
#   Measurement: 1
# Foil: Zirconium-11 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium11_180deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.4463, name='Zirconium-11 Zr90(n,2n)Zr89', density=6.52, thickness=0.050800000000000005), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ec123f0>}}
#   Measurement: 1
# Foil: Zirconium-10 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium10_150deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.4445, name='Zirconium-10 Zr90(n,2n)Zr89', density=6.52, thickness=0.050800000000000005), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ef60830>}}
#   Measurement: 1
# Foil: Zirconium-12 Zr90(n,2n)Zr89
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Zirconium12_under_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Zr90', energy=None, intensity=None, half_life=None, atomic_mass=89.90469876, abundance=0.515), product=Nuclide(name='Zr89', energy=[909.15], intensity=[0.9904], half_life=282276.0, atomic_mass=None, abundance=1.0), cross_section=6.2389e-25, type='(n,2n)'), mass=0.1115, name='Zirconium-12 Zr90(n,2n)Zr89', density=6.52, thickness=0.012700000000000001), 'distance_to_source': 2.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951e6a4160>}}
#   Measurement: 1
# Foil: Niobium-10 Nb93(n,2n)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Niobium10_60deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Nb93', energy=None, intensity=None, half_life=None, atomic_mass=92.90637, abundance=1.0), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=885600.0, atomic_mass=None, abundance=1.0), cross_section=4.5966e-25, type='(n,2n)'), mass=1.1373, name='Niobium-10 Nb93(n,2n)Nb92m', density=8.57, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951e6a4270>}}
#   Measurement: 1
# Foil: Niobium-11 Nb93(n,2n)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Niobium11_150deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Nb93', energy=None, intensity=None, half_life=None, atomic_mass=92.90637, abundance=1.0), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=885600.0, atomic_mass=None, abundance=1.0), cross_section=4.5966e-25, type='(n,2n)'), mass=1.0829, name='Niobium-11 Nb93(n,2n)Nb92m', density=8.57, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ec3dd50>}}
#   Measurement: 1
# Foil: Niobium-12 Nb93(n,2n)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Niobium12_120deg_count2/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Nb93', energy=None, intensity=None, half_life=None, atomic_mass=92.90637, abundance=1.0), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=885600.0, atomic_mass=None, abundance=1.0), cross_section=4.5966e-25, type='(n,2n)'), mass=1.0944, name='Niobium-12 Nb93(n,2n)Nb92m', density=8.57, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ec3de50>}}
#   Measurement: 1
# Foil: Niobium-13 Nb93(n,2n)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/NaI/nGen_charac_NaI/DAQ/Niobium13_180deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Nb93', energy=None, intensity=None, half_life=None, atomic_mass=92.90637, abundance=1.0), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=885600.0, atomic_mass=None, abundance=1.0), cross_section=4.5966e-25, type='(n,2n)'), mass=1.1285, name='Niobium-13 Nb93(n,2n)Nb92m', density=8.57, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7f951ec1f5c0>}}
#   Measurement: 1

# %%
from process_foil_data import irradiations, time_generator_off

# %% [markdown]
# ### Niobium Packet #3 Results
#
# The activity of Nb-92m is measured using its 934 keV gamma peak and used to determine the neutron rate during the irradiation. Nb-92m is formed from the Nb-93(n,2n) reaction, which has a threshold energy of 8.9 MeV.
#
# The gamma spectrum obtained from the various measurements of the Niobium Packet #3 after irradiation are used to calculate the neutron rate of the overall irradiation.

# %% [markdown]
# Add the one-group cross sections from the simulation results using the IRDF-II cross section database

# %%
# from process_foil_data import calculate_xs_from_sim
# foil_measurements = calculate_xs_from_sim(foil_measurements)

# %%
from process_foil_data import calculate_neutron_flux_from_foil
foil_rates = {}
foil_rates_err = {}
all_foil_rates = {}
all_foil_rates_err = {}
for foil_name in foil_measurements.keys():
    print(f"\nProcessing foil: {foil_name}")
    gamma_energy = foil_measurements[foil_name]['foil'].reaction.product.energy
    print(gamma_energy)
    nuclide = foil_measurements[foil_name]['foil'].reaction.reactant.name
    angle = foil_measurements[foil_name]['foil'].angle
    if foil_rates.get(nuclide) is None:
        foil_rates[nuclide] = {}
        foil_rates_err[nuclide] = {}
    if foil_rates[nuclide].get(angle) is None:
        foil_rates[nuclide][angle] = []
        foil_rates_err[nuclide][angle] = []

    if all_foil_rates.get(angle) is None:
        all_foil_rates[angle] = []
        all_foil_rates_err[angle] = []
    detector_efficiency = {}
    detector_efficiency_err = {}
    for ch in channels:
        detector_efficiency[ch], detector_efficiency_err[ch] = \
            calculate_efficiency_at_energy(gamma_energy, ch, method='propagation')
        print(f"Detector efficiency for Ch {ch} at {gamma_energy} keV: {detector_efficiency[ch]:.6f} ± {detector_efficiency_err[ch]:.6f}")

    print('\nWith Detector Efficiency Error:')

    neutron_rates, neutron_rates_err = calculate_neutron_flux_from_foil(
                                        foil_measurements,
                                        foil_name,
                                        background_meas,
                                        calibration_coeffs,
                                        efficiency_coeffs,
                                        search_width=search_width,
                                        detector_efficiency=detector_efficiency,
                                        detector_efficiency_err=detector_efficiency_err
                                        )


    for count_name in neutron_rates.keys():
        print(count_name)
        for ch in np.sort(list(neutron_rates[count_name].keys())):
            neutron_rate = neutron_rates[count_name][ch]
            neutron_rate_err = neutron_rates_err[count_name][ch]
            print(f"\t Ch {ch}: Neutron rate: {neutron_rate[0]:.3e} +/- {neutron_rate_err[0]:.3e} n/s")
            if neutron_rate[0] > 0:

                all_foil_rates[angle].append(neutron_rate[0])
                all_foil_rates_err[angle].append(neutron_rate_err[0])
                foil_rates[nuclide][angle].append(neutron_rate[0])
                foil_rates_err[nuclide][angle].append(neutron_rate_err[0])
            else:
                print("Negative rate value, skipping addition to totals.")


# print('\nWithout Detector Efficiency Error:')

# neutron_fluxs, neutron_flux_errs = calculate_neutron_flux_from_foil(
#                                     foil_measurements,
#                                     foil_name,
#                                     background_meas,
#                                     calibration_coeffs,
#                                     efficiency_coeffs,
#                                     search_width=search_width,
#                                     detector_efficiency=detector_efficiency,
#                                     detector_efficiency_err=0.0
#                                     )

# for count_name in neutron_rates.keys():
#     print(count_name)
#     for ch in np.sort(list(neutron_rates[count_name].keys())):
#         neutron_rate = neutron_rates[count_name][ch]
#         neutron_rate_err = neutron_rate_errs[count_name][ch]
#         print(f"\t Ch {ch}: Neutron rate: {neutron_rate[0]:.3e} +/- {neutron_rate_err[0]:.3e} n/s")
# Out:
# Processing foil: Aluminum-1 Al27(n,alpha)Na24
# [1368.63]
# Detector efficiency for Ch 0 at [1368.63] keV: 0.010291 ± 0.000017
# Detector efficiency for Ch 1 at [1368.63] keV: 0.013925 ± 0.000019
#
# With Detector Efficiency Error:
# [1368.63]
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 0: [14792803.9627978] +/- [44930.97831601]
# number_of_decays_measured: [14801684.97378207]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [4.9630352e+09]
# number_of_decays_measured: [44957.95308786]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [15074493.49542466]
# [1368.63]
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 1: [14907364.470767] +/- [38322.70739127]
# number_of_decays_measured: [14916314.2593226]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [5.00147064e+09]
# number_of_decays_measured: [38345.71482016]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [12857396.49899685]
# Count 1
# 	 Ch 0: Neutron rate: 2.710e+05 +/- 8.232e+02 n/s
# 	 Ch 1: Neutron rate: 2.730e+05 +/- 7.019e+02 n/s
#
# Processing foil: Zirconium-2 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-2 Zr90(n,2n)Zr89 Count 1 Channel 0: [383321.74538622] +/- [5367.73726181]
# number_of_decays_measured: [387037.30349982]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.64699833e+08]
# number_of_decays_measured: [5419.76702525]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [3706648.98762174]
# [909.15]
# Gamma emitted for Zirconium-2 Zr90(n,2n)Zr89 Count 1 Channel 1: [361556.38422671] +/- [4229.62570859]
# number_of_decays_measured: [365060.96953423]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.49669934e+08]
# number_of_decays_measured: [4270.62369607]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2920734.95517375]
# Count 1
# 	 Ch 0: Neutron rate: 5.262e+05 +/- 7.369e+03 n/s
# 	 Ch 1: Neutron rate: 4.965e+05 +/- 5.808e+03 n/s
#
# Processing foil: Zirconium-3 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-3 Zr90(n,2n)Zr89 Count 1 Channel 1: [243929.41899872] +/- [3467.98464862]
# number_of_decays_measured: [246293.83986139]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.54425411e+08]
# number_of_decays_measured: [3501.6000087]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [3617207.88571269]
# [909.15]
# Gamma emitted for Zirconium-3 Zr90(n,2n)Zr89 Count 1 Channel 0: [257116.62596701] +/- [4388.01955737]
# number_of_decays_measured: [259608.87112985]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.68180047e+08]
# number_of_decays_measured: [4430.55286488]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [4576830.79765314]
# Count 1
# 	 Ch 0: Neutron rate: 6.161e+05 +/- 1.052e+04 n/s
# 	 Ch 1: Neutron rate: 5.843e+05 +/- 8.307e+03 n/s
#
# Processing foil: Zirconium-9 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-9 Zr90(n,2n)Zr89 Count 1 Channel 0: [276614.67958222] +/- [4552.66623068]
# number_of_decays_measured: [279295.92041824]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.90844872e+08]
# number_of_decays_measured: [4596.79546716]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [4786874.04053218]
# [909.15]
# Gamma emitted for Zirconium-9 Zr90(n,2n)Zr89 Count 1 Channel 1: [257300.57955743] +/- [3562.48457807]
# number_of_decays_measured: [259794.60779224]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [2.70537176e+08]
# number_of_decays_measured: [3597.01593101]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [3745753.38548825]
# Count 1
# 	 Ch 0: Neutron rate: 6.313e+05 +/- 1.039e+04 n/s
# 	 Ch 1: Neutron rate: 5.871e+05 +/- 8.128e+03 n/s
#
# Processing foil: Zirconium-11 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-11 Zr90(n,2n)Zr89 Count 1 Channel 0: [540957.28051759] +/- [6391.36483904]
# number_of_decays_measured: [546200.80827705]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [5.68658895e+08]
# number_of_decays_measured: [6453.31667916]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [6718657.09102808]
# [909.15]
# Gamma emitted for Zirconium-11 Zr90(n,2n)Zr89 Count 1 Channel 1: [488544.66193734] +/- [4925.98453496]
# number_of_decays_measured: [493280.15139069]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [5.13562305e+08]
# number_of_decays_measured: [4973.73236567]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [5178236.84917749]
# Count 1
# 	 Ch 0: Neutron rate: 6.718e+05 +/- 7.938e+03 n/s
# 	 Ch 1: Neutron rate: 6.064e+05 +/- 6.115e+03 n/s
#
# Processing foil: Zirconium-10 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-10 Zr90(n,2n)Zr89 Count 1 Channel 1: [1109335.94044701] +/- [7491.52992023]
# number_of_decays_measured: [1120088.79285845]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [1.17086567e+09]
# number_of_decays_measured: [7564.14571914]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [7907050.39526159]
# [909.15]
# Gamma emitted for Zirconium-10 Zr90(n,2n)Zr89 Count 1 Channel 0: [1441522.93858705] +/- [10569.72352951]
# number_of_decays_measured: [1455495.69728095]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [1.52147754e+09]
# number_of_decays_measured: [10672.17642318]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [11155977.15042704]
# Count 1
# 	 Ch 0: Neutron rate: 7.827e+05 +/- 5.739e+03 n/s
# 	 Ch 1: Neutron rate: 6.021e+05 +/- 4.066e+03 n/s
#
# Processing foil: Zirconium-12 Zr90(n,2n)Zr89
# [909.15]
# Detector efficiency for Ch 0 at [909.15] keV: 0.013455 ± 0.000020
# Detector efficiency for Ch 1 at [909.15] keV: 0.020432 ± 0.000025
#
# With Detector Efficiency Error:
# [909.15]
# Gamma emitted for Zirconium-12 Zr90(n,2n)Zr89 Count 1 Channel 1: [1139552.9929484] +/- [7596.24528411]
# number_of_decays_measured: [1150598.74086067]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [4.79485427e+09]
# number_of_decays_measured: [7669.87609461]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [31962435.60423432]
# [909.15]
# Gamma emitted for Zirconium-12 Zr90(n,2n)Zr89 Count 1 Channel 0: [1242794.22633567] +/- [9786.33901916]
# number_of_decays_measured: [1254840.69702713]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [5.22925853e+09]
# number_of_decays_measured: [9881.198525]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  6.2389e-25
# flux before time and self-attenuation correction: [41177610.64870471]
# Count 1
# 	 Ch 0: Neutron rate: 1.180e+07 +/- 9.288e+04 n/s
# 	 Ch 1: Neutron rate: 1.083e+07 +/- 7.219e+04 n/s
#
# Processing foil: Niobium-10 Nb93(n,2n)Nb92m
# [934.44]
# Detector efficiency for Ch 0 at [934.44] keV: 0.013151 ± 0.000020
# Detector efficiency for Ch 1 at [934.44] keV: 0.019881 ± 0.000024
#
# With Detector Efficiency Error:
# [934.44]
# Gamma emitted for Niobium-10 Nb93(n,2n)Nb92m Count 1 Channel 0: [2361650.80050165] +/- [13857.77674243]
# number_of_decays_measured: [2381896.9243587]
# nnumber of atoms in foil:  7.371744908341592e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [7.0293627e+08]
# number_of_decays_measured: [13976.57765247]
# nnumber of atoms in foil:  7.371744908341592e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [4124713.9029245]
# [934.44]
# Gamma emitted for Niobium-10 Nb93(n,2n)Nb92m Count 1 Channel 1: [2105291.19163393] +/- [10609.61120586]
# number_of_decays_measured: [2123339.57804733]
# nnumber of atoms in foil:  7.371744908341592e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [6.26631819e+08]
# number_of_decays_measured: [10700.566017]
# nnumber of atoms in foil:  7.371744908341592e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [3157909.93453073]
# Count 1
# 	 Ch 0: Neutron rate: 7.528e+05 +/- 4.417e+03 n/s
# 	 Ch 1: Neutron rate: 6.712e+05 +/- 3.382e+03 n/s
#
# Processing foil: Niobium-11 Nb93(n,2n)Nb92m
# [934.44]
# Detector efficiency for Ch 0 at [934.44] keV: 0.013151 ± 0.000020
# Detector efficiency for Ch 1 at [934.44] keV: 0.019881 ± 0.000024
#
# With Detector Efficiency Error:
# [934.44]
# Gamma emitted for Niobium-11 Nb93(n,2n)Nb92m Count 1 Channel 1: [439911.34284829] +/- [4734.77456697]
# number_of_decays_measured: [443682.64533363]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1.37515647e+08]
# number_of_decays_measured: [4775.36517092]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1480083.65220854]
# [934.44]
# Gamma emitted for Niobium-11 Nb93(n,2n)Nb92m Count 1 Channel 0: [438689.36057964] +/- [5812.71083797]
# number_of_decays_measured: [442450.18717059]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1.37133657e+08]
# number_of_decays_measured: [5862.54244879]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1817044.96478471]
# Count 1
# 	 Ch 0: Neutron rate: 6.730e+05 +/- 8.917e+03 n/s
# 	 Ch 1: Neutron rate: 6.757e+05 +/- 7.273e+03 n/s
#
# Processing foil: Niobium-12 Nb93(n,2n)Nb92m
# [934.44]
# Detector efficiency for Ch 0 at [934.44] keV: 0.013151 ± 0.000020
# Detector efficiency for Ch 1 at [934.44] keV: 0.019881 ± 0.000024
#
# With Detector Efficiency Error:
# [934.44]
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 0: [515672.5760238] +/- [6309.15944507]
# number_of_decays_measured: [520093.36966596]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1.59504618e+08]
# number_of_decays_measured: [6363.24704495]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1951509.7618251]
# [934.44]
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 1: [478972.31305396] +/- [4943.36077274]
# number_of_decays_measured: [483078.48013511]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1.48152722e+08]
# number_of_decays_measured: [4985.73955899]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [1529049.45392731]
# Count 1
# 	 Ch 0: Neutron rate: 6.584e+05 +/- 8.055e+03 n/s
# 	 Ch 1: Neutron rate: 6.122e+05 +/- 6.319e+03 n/s
#
# Processing foil: Niobium-13 Nb93(n,2n)Nb92m
# [934.44]
# Detector efficiency for Ch 0 at [934.44] keV: 0.013151 ± 0.000020
# Detector efficiency for Ch 1 at [934.44] keV: 0.019881 ± 0.000024
#
# With Detector Efficiency Error:
# [934.44]
# Gamma emitted for Niobium-13 Nb93(n,2n)Nb92m Count 1 Channel 0: [1678577.47803915] +/- [11572.91651965]
# number_of_decays_measured: [1692967.70351906]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [5.03518159e+08]
# number_of_decays_measured: [11672.12962143]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [3471495.17810351]
# [934.44]
# Gamma emitted for Niobium-13 Nb93(n,2n)Nb92m Count 1 Channel 1: [1569674.70115794] +/- [9091.78402064]
# number_of_decays_measured: [1583131.31735546]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [4.708509e+08]
# number_of_decays_measured: [9169.72669757]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [2727236.84945122]
# Count 1
# 	 Ch 0: Neutron rate: 7.092e+05 +/- 4.890e+03 n/s
# 	 Ch 1: Neutron rate: 6.629e+05 +/- 3.839e+03 n/s

# %%
from process_foil_data import calculate_neutron_flux_from_foil_with_xs
foil_rates = {}
foil_rates_err = {}
all_foil_rates = {}
all_foil_rates_err = {}
for foil_name in foil_measurements.keys():

    neutron_rates, neutron_rates_err = calculate_neutron_flux_from_foil_with_xs(
                                        foil_measurements,
                                        foil_name,
                                        background_meas,
                                        calibration_coeffs,
                                        efficiency_coeffs,
                                        search_width=search_width,
                                        detector_efficiency=detector_efficiency,
                                        detector_efficiency_err=detector_efficiency_err
                                        )


    for count_name in neutron_rates.keys():
        print(count_name)
        for reaction in neutron_rates[count_name].keys():
            print(f"\t Reaction: {reaction}")
            for ch in np.sort(list(neutron_rates[count_name][reaction].keys())):
                neutron_rate = neutron_rates[count_name][reaction][ch]
                neutron_rate_err = neutron_rates_err[count_name][reaction][ch]
                print(f"\t \tCh {ch}: Neutron rate: ", neutron_rate, " n/s")
            else:
                print("Negative rate value, skipping addition to totals.")


# print('\nWithout Detector Efficiency Error:')

# neutron_fluxs, neutron_flux_errs = calculate_neutron_flux_from_foil(
#                                     foil_measurements,
#                                     foil_name,
#                                     background_meas,
#                                     calibration_coeffs,
#                                     efficiency_coeffs,
#                                     search_width=search_width,
#                                     detector_efficiency=detector_efficiency,
#                                     detector_efficiency_err=0.0
#                                     )

# for count_name in neutron_rates.keys():
#     print(count_name)
#     for ch in np.sort(list(neutron_rates[count_name].keys())):
#         neutron_rate = neutron_rates[count_name][ch]
#         neutron_rate_err = neutron_rate_errs[count_name][ch]
#         print(f"\t Ch {ch}: Neutron rate: {neutron_rate[0]:.3e} +/- {neutron_rate_err[0]:.3e} n/s")
# Out:
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Aluminum-1_foil_-90deg_Al27(n,alpha)Na24
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25])}
# [1368.63]
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 0: [11576025.08061822] +/- [34345.11906003]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25] cm^2
# number_of_decays_measured: [11582974.86553755]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 2.56596359e+14 1.24927285e+10
#  4.48819134e+09 3.88335673e+09]
# number_of_decays_measured: [34365.73850313]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 7.61300398e+11 3.70649032e+07
#  1.33160964e+07 1.15216016e+07]
# [1368.63]
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 1: [10441082.12623504] +/- [26253.65972512]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25] cm^2
# number_of_decays_measured: [10447350.53655698]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 2.31438999e+14 1.12679096e+10
#  4.04815764e+09 3.50262256e+09]
# number_of_decays_measured: [26269.42137795]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 0.00000000e+00 1.83499361e-30 3.76901394e-26
#  1.04909226e-25 1.21248886e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 5.81943582e+11 2.83326825e+07
#  1.01789213e+07 8.80719639e+06]
# Count 1
# 	 Reaction: Al27(n,alpha)Na24
# 	 	Ch 0: Neutron rate:  [0.00000000e+00 0.00000000e+00 1.40131376e+10 6.82247887e+05
#  2.45107308e+05 2.12076323e+05]  n/s
# 	 	Ch 1: Neutron rate:  [0.00000000e+00 0.00000000e+00 1.26342409e+10 6.15114505e+05
#  2.20988680e+05 1.91207953e+05]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-2_foil_90deg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25])}
# [909.15]
# Gamma emitted for Zirconium-2 Zr90(n,2n)Zr89 Count 1 Channel 0: [392191.69800138] +/- [5492.32610868]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25] cm^2
# number_of_decays_measured: [395993.23303855]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.73462826e+08]
# number_of_decays_measured: [5545.56351845]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         3829624.71999324]
# [909.15]
# Gamma emitted for Zirconium-2 Zr90(n,2n)Zr89 Count 1 Channel 1: [371574.40721935] +/- [4347.11266394]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25] cm^2
# number_of_decays_measured: [375176.09775782]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.59087044e+08]
# number_of_decays_measured: [4389.24945875]
# nnumber of atoms in foil:  2.3436412457426045e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17871742e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         3031103.72345265]
# Count 1
# 	 Reaction: Zr90(n,2n)Zr89
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         543665.80697628]  n/s
# 	 	Ch 1: Neutron rate:  [     0.              0.              0.              0.
#       0.         515194.20554545]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25])}
# [909.15]
# Gamma emitted for Zirconium-3 Zr90(n,2n)Zr89 Count 1 Channel 1: [250688.22795555] +/- [3564.2379972]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25] cm^2
# number_of_decays_measured: [253118.16231376]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.64106472e+08]
# number_of_decays_measured: [3598.78634613]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         3755016.06628524]
# [909.15]
# Gamma emitted for Zirconium-3 Zr90(n,2n)Zr89 Count 1 Channel 0: [263066.22918245] +/- [4489.76672592]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25] cm^2
# number_of_decays_measured: [265616.14416644]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.77147014e+08]
# number_of_decays_measured: [4533.28627415]
# nnumber of atoms in foil:  1.5516188288710974e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17673862e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         4730084.29934405]
# Count 1
# 	 Reaction: Zr90(n,2n)Zr89
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         636740.16609096]  n/s
# 	 	Ch 1: Neutron rate:  [     0.              0.              0.              0.
#       0.         606502.89344002]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-9_foil_60deg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25])}
# [909.15]
# Gamma emitted for Zirconium-9 Zr90(n,2n)Zr89 Count 1 Channel 0: [283015.46203218] +/- [4658.2475056]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25] cm^2
# number_of_decays_measured: [285758.74599372]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 3.00589191e+08]
# number_of_decays_measured: [4703.40014701]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         4947499.47183464]
# [909.15]
# Gamma emitted for Zirconium-9 Zr90(n,2n)Zr89 Count 1 Channel 1: [264429.87732253] +/- [3661.36982194]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25] cm^2
# number_of_decays_measured: [266993.01022065]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 2.80849542e+08]
# number_of_decays_measured: [3696.85967482]
# nnumber of atoms in foil:  1.5392003589201506e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17633745e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         3888721.07771895]
# Count 1
# 	 Reaction: Zr90(n,2n)Zr89
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         652471.51379434]  n/s
# 	 	Ch 1: Neutron rate:  [     0.              0.              0.              0.
#       0.         609442.86075305]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-11_foil_0deg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25])}
# [909.15]
# Gamma emitted for Zirconium-11 Zr90(n,2n)Zr89 Count 1 Channel 0: [553474.87312164] +/- [6539.89637438]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25] cm^2
# number_of_decays_measured: [558839.73457354]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.88699136e+08]
# number_of_decays_measured: [6603.28793859]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         6956108.63840189]
# [909.15]
# Gamma emitted for Zirconium-11 Zr90(n,2n)Zr89 Count 1 Channel 1: [502081.2826962] +/- [5062.93215415]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25] cm^2
# number_of_decays_measured: [506947.98333623]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 5.34034753e+08]
# number_of_decays_measured: [5112.00742543]
# nnumber of atoms in foil:  1.5395453164187877e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16596993e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         5385147.42084859]
# Count 1
# 	 Reaction: Zr90(n,2n)Zr89
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         695496.54796705]  n/s
# 	 	Ch 1: Neutron rate:  [     0.             0.             0.             0.
#       0.        630622.6259899]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-10_foil_30deg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25])}
# [909.15]
# Gamma emitted for Zirconium-10 Zr90(n,2n)Zr89 Count 1 Channel 1: [1140073.47805606] +/- [7700.65892393]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25] cm^2
# number_of_decays_measured: [1151124.27105822]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.21506244e+09]
# number_of_decays_measured: [7775.30182141]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         8207174.01130519]
# [909.15]
# Gamma emitted for Zirconium-10 Zr90(n,2n)Zr89 Count 1 Channel 0: [1474879.35604272] +/- [10817.0397868]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25] cm^2
# number_of_decays_measured: [1489175.4402693]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.57189036e+09]
# number_of_decays_measured: [10921.88993013]
# nnumber of atoms in foil:  1.5333360814433145e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.17854565e-25]
# flux before time and self-attenuation correction: [       0.                0.                0.                0.
#         0.         11528536.54400897]
# Count 1
# 	 Reaction: Zr90(n,2n)Zr89
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         808609.65692543]  n/s
# 	 	Ch 1: Neutron rate:  [     0.             0.             0.             0.
#       0.        624865.1841129]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25])}
# [909.15]
# Gamma emitted for Zirconium-12 Zr90(n,2n)Zr89 Count 1 Channel 1: [1171127.78621089] +/- [7808.33892032]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16929674e-25] cm^2
# number_of_decays_measured: [1182479.59027756]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16929674e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 4.98330578e+09]
# number_of_decays_measured: [7884.02556575]
# nnumber of atoms in foil:  3.8462761098071894e+20
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 6.16929674e-25]
# flux before time and self-attenuation correction: [       0.              0.              0.              0.
#         0.       33225529.183755]
# [909.15]
# Gamma emitted for Zirconium-12 Zr90(n,2n)Zr89 Count 1 Channel 0: [1271552.11975205] +/- [10014.988451]
# ...
#  4.5953688e-25] cm^2
# number_of_decays_measured: [443682.64533363]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.5953688e-25]
# flux before time and self-attenuation correction: [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  1.3755249e+08]
# number_of_decays_measured: [4775.36517092]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.5953688e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         1480480.19985125]
# [934.44]
# Gamma emitted for Niobium-11 Nb93(n,2n)Nb92m Count 1 Channel 0: [438689.36057964] +/- [5812.71083797]
# cross section for foil reaction: [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.5953688e-25] cm^2
# number_of_decays_measured: [442450.18717059]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.5953688e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 1.37170398e+08]
# number_of_decays_measured: [5862.54244879]
# nnumber of atoms in foil:  7.019135286417928e+21
# cross section:  [0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00
#  4.5953688e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#        0.         1817531.79192884]
# Count 1
# 	 Reaction: Nb93(n,2n)Nb92m
# 	 	Ch 0: Neutron rate:  [     0.              0.              0.              0.
#       0.         673148.07505207]  n/s
# 	 	Ch 1: Neutron rate:  [     0.              0.              0.              0.
#       0.         675878.32133792]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Niobium-12_foil_60deg_Nb93(n,2n)Nb92m
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25])}
# [934.44]
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 0: [515672.5760238] +/- [6309.15944507]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25] cm^2
# number_of_decays_measured: [520093.36966596]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  3.00714396e+08 1.59547486e+08]
# number_of_decays_measured: [6363.24704495]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#  3679185.51033119 1952034.24158261]
# [934.44]
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 1: [478972.31305396] +/- [4943.36077274]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25] cm^2
# number_of_decays_measured: [483078.48013511]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.79312642e+08 1.48192539e+08]
# number_of_decays_measured: [4985.73955899]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  2.43812380e-25 4.59536497e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#  2882720.19208756 1529460.39498562]
# Count 1
# 	 Reaction: Nb93(n,2n)Nb92m
# 	 	Ch 0: Neutron rate:  [      0.               0.               0.               0.
#  1241198.07798968  658531.93377147]  n/s
# 	 	Ch 1: Neutron rate:  [      0.               0.               0.               0.
#  1154268.96394022  612410.69124687]  n/s
# Negative rate value, skipping addition to totals.
# Read 23 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17673862e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16929674e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17871742e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.16596993e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17633745e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 6.17854565e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([5.49800409e-27, 1.02755741e-25, 3.94288237e-25, 6.29471112e-25,
#        6.23348593e-25, 3.55605375e-25]), 'Nickel-4_foil_90deg_Ni58(n,p)Co58': array([2.97657230e-27, 1.28353514e-25, 2.72156318e-25, 6.25983152e-25,
#        6.00307789e-25, 3.56410560e-25]), 'Indium-1_foil_underdeg_In115(n,gamma)In116m': array([1.76897845e-25, 9.08170728e-26, 2.11984046e-26, 2.55197048e-27,
#        6.90572527e-28, 9.70140095e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.12391844e-25, 7.68121692e-26, 3.86799867e-26, 3.10823736e-27,
#        6.17457580e-28, 9.70066885e-28]), "Indium-1_foil_underdeg_In115(n,n')In115m": array([8.42145200e-26, 3.25636269e-25, 3.32198938e-25, 3.25591035e-25,
#        2.15344470e-25, 6.59440498e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([5.70894097e-26, 3.38637908e-25, 3.36735663e-25, 3.36256473e-25,
#        2.50886840e-25, 6.60280550e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 0.00000000e+00, 9.18617507e-29, 7.35901256e-27,
#        3.93716204e-26, 6.24463062e-26]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        2.43812380e-25, 4.59536497e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 0.0000000e+00,
#        0.0000000e+00, 4.5953688e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        3.29147805e-25, 4.59536593e-25]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 0.00000000e+00, 1.83499361e-30, 3.76901394e-26,
#        1.04909226e-25, 1.21248886e-25]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 8.46839924e-29, 8.28281646e-27, 7.46060528e-26,
#        9.93829186e-26, 7.51424841e-26]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([4.34129233e-30, 5.85549192e-28, 2.95670616e-26, 8.25907306e-26,
#        1.17683669e-25, 7.12266157e-26]), 'Indium-1_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        4.88491168e-25, 1.33456224e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.60696442e-25, 1.33417455e-24]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.36512999e-25, 8.86751993e-25])}
# Looking for cross section with key: Niobium-13_foil_0deg_Nb93(n,2n)Nb92m
# Available keys in foil_xs_dict: ['Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Nickel-4_foil_90deg_Ni58(n,p)Co58', 'Indium-1_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', "Indium-1_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Indium-1_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64']
# xs_dict: {'Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.38434973e-25, 4.59445641e-25])}
# [934.44]
# Gamma emitted for Niobium-13 Nb93(n,2n)Nb92m Count 1 Channel 0: [1678577.47803915] +/- [11572.91651965]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25] cm^2
# number_of_decays_measured: [1692967.70351906]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.67188357e+09 5.03753080e+08]
# number_of_decays_measured: [11672.12962143]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25]
# flux before time and self-attenuation correction: [       0.                0.                0.                0.
#  11526765.54520163  3473114.83841133]
# [934.44]
# Gamma emitted for Niobium-13 Nb93(n,2n)Nb92m Count 1 Channel 1: [1569674.70115794] +/- [9091.78402064]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25] cm^2
# number_of_decays_measured: [1583131.31735546]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.56341508e+09 4.71070580e+08]
# number_of_decays_measured: [9169.72669757]
# nnumber of atoms in foil:  7.314705116559824e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  1.38434973e-25 4.59445641e-25]
# flux before time and self-attenuation correction: [      0.               0.               0.               0.
#  9055527.41312816 2728509.26869666]
# Count 1
# 	 Reaction: Nb93(n,2n)Nb92m
# 	 	Ch 0: Neutron rate:  [      0.               0.               0.               0.
#  2354941.40120083  709564.35194472]  n/s
# 	 	Ch 1: Neutron rate:  [      0.               0.               0.               0.
#  2200949.11915229  663165.13633768]  n/s
# Negative rate value, skipping addition to totals.

# %% [markdown]
# ## Angular Characterization Results

# %%
fig, axes = plt.subplots(figsize=(8,6))
formats = {'Nb93': 'x',
           'Zr90': '^',}
for foil_type in foil_rates.keys():
    for angle in foil_rates[foil_type].keys():
        axes.errorbar(
            [angle]*len(foil_rates[foil_type][angle]),
            foil_rates[foil_type][angle],
            yerr=foil_rates_err[foil_type][angle],
            fmt=formats.get(foil_type, 'o'),
            label=f"{foil_type} - {angle}°"
        )
axes.set_xlabel("Foil Angle (degrees)")
axes.set_ylabel("Neutron rate (n/s)")
axes.set_ylim(bottom=0)
axes.legend()

# %%
import json
processed_data_file = "../../data/processed_data.json"

processed_data = {'foils': 
                       {'NaI': {}
                  }
}
for foil_type in foil_rates.keys():
    processed_data['foils']['NaI'][foil_type] = {}
    for angle in foil_rates[foil_type].keys():
        processed_data['foils']['NaI'][foil_type][angle] = {
            'rate': np.mean(foil_rates[foil_type][angle]),
            'rate_err': np.sqrt(np.sum(np.square(foil_rates_err[foil_type][angle]))) / len(foil_rates_err[foil_type][angle]),
            'units': 'n/s',
            'number_of_measurements': len(foil_rates[foil_type][angle])
        }


try:
    with open(processed_data_file, "r") as f:
        existing_data = json.load(f)
except FileNotFoundError:
    print(f"Processed data file not found, creating it in {processed_data_file}")
    existing_data = {}

existing_data.update(processed_data)

with open(processed_data_file, "w") as f:
    json.dump(existing_data, f, indent=4)

print(f"Processed data stored in {processed_data_file}")
# Out:
# Processed data stored in ../../data/processed_data.json
