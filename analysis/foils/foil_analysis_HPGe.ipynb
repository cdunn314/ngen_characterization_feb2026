# %% [markdown]
# # Activation Foil Analysis: LaBr Detectors
#
# This notebook processes the calibration data from a LaBr detector to energy calibrate the detectors and determine total detector efficiencies. Then, LaBr measurements of activation foils irradiated during the run with a D-T neutron (14.1 MeV) generator are used to determine the average neutron rate during the run.

# %% [markdown]
# ## Obtaining the Data
# First, the NaI detector measurement data is obtained from Zenodo and extracted

# %%
import numpy as np
from datetime import datetime
import json

# %%
from process_foil_data import get_data
check_source_measurements, background_meas, foil_measurements = get_data(download_from_raw=True,
                                                                         h5_filename='activation_data.h5',
                                                                         detector_type='HPGe')
# Out:
# /home/cdunn314/libra/ngen_characterization_v2/neutronics
# Read in properties of Aluminum-1 Al27(n,alpha)Na24 foil
# Read in properties of Indium-1 In115(n,n')In115m foil
# Read in properties of Indium-1 In115(n,gamma)In116m foil
# Read in properties of Indium-2 In115(n,n')In115m foil
# Read in properties of Indium-2 In115(n,gamma)In116m foil
# Read in properties of Indium-3 In115(n,n')In115m foil
# Read in properties of Indium-3 In115(n,gamma)In116m foil
# Read in properties of Titanium-1 Ti48(n,p)Sc48 foil
# Read in properties of Nickel-1 Ni58(n,p)Co58 foil
# Read in properties of Molybdenum-1 Mo92(n,p)Nb92m foil
# Read in properties of Niobium-12 Nb93(n,2n)Nb92m foil
# Checking if measurement directory exists at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ...
# Measurement directory ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ already exists. Skipping download and extraction.
# Processing Ba133 Count 1...
# Found data file: Data_CH0@V1725_292_Ba133_1_0uCi_Mar2014_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Ba133_1_0uCi_Mar2014_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Ba133_1_0uCi_Mar2014_count1/Ba133_1_0uCi_Mar2014_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Assuming real count time is the time between start and stop time:  1680.398
# Assuming live count time is the time between first and last event:  1680.49194552
# Processing Ba133 Count 2...
# Found data file: Data_CH0@V1725_292_Ba133_1_0uCi_Mar2014_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Ba133_1_0uCi_Mar2014_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Ba133_1_0uCi_Mar2014_count2/Ba133_1_0uCi_Mar2014_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Co60 Count 1...
# Found data file: Data_CH0@V1725_292_Co60_0_872uCi_19Mar2014_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Co60_0_872uCi_19Mar2014_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Co60_0_872uCi_19Mar2014_count1/Co60_0_872uCi_19Mar2014_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Co60 Count 2...
# Found data file: Data_CH0@V1725_292_Co60_0_872uCi_19Mar2014_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Co60_0_872uCi_19Mar2014_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Co60_0_872uCi_19Mar2014_count2/Co60_0_872uCi_19Mar2014_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Cs137 Count 1...
# Found data file: Data_CH0@V1725_292_Cs137_9_38_29Sep2023_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Cs137_9_38uCi_29Sep2023_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Cs137_9_38uCi_29Sep2023_count1/Cs137_9_38uCi_29Sep2023_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Cs137 Count 2...
# Found data file: Data_CH0@V1725_292_Cs137_9_38_29Sep2023_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Cs137_9_38uCi_29Sep2023_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Cs137_9_38uCi_29Sep2023_count2/Cs137_9_38uCi_29Sep2023_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Na22 Count 1...
# Found data file: Data_CH0@V1725_292_Na22_9_98_29Sep2023_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Na22_9_98uCi_29Sep2023_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Na22_9_98uCi_29Sep2023_count1/Na22_9_98uCi_29Sep2023_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Na22 Count 2...
# Found data file: Data_CH0@V1725_292_Na22_9_98_29Sep2023_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Na22_9_98uCi_29Sep2023_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Na22_9_98uCi_29Sep2023_count2/Na22_9_98uCi_29Sep2023_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Mn54 Count 1...
# Found data file: Data_CH0@V1725_292_Mn54_6_27uCi_2May2016.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Mn54_6_27uCi_2May2016_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Mn54_6_27uCi_2May2016_count1/Mn54_6_27uCi_2May2016_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Mn54 Count 2...
# Found data file: Data_CH0@V1725_292_Mn54_6_27uCi_2May2016_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Mn54_6_27uCi_2May2016_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Mn54_6_27uCi_2May2016_count2/Mn54_6_27uCi_2May2016_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing background...
# Found data file: Data_CH0@V1725_292_Background_long_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Background_long_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Background_long_count1/Background_long_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Aluminum-1 Al27(n,alpha)Na24 Count 1...
# Found data file: Data_CH0@V1725_292_Aluminum1_270deg_short_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Aluminum1_270deg_short_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Aluminum1_270deg_short_count1/Aluminum1_270deg_short_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-1 In115(n,n')In115m Count 1...
# Found data file: Data_CH0@V1725_292_Indium1_90deg_short_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/Indium1_90deg_short_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-1 In115(n,n')In115m Count 2...
# Found data file: Data_CH0@V1725_292_Indium1_90deg_long_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/Indium1_90deg_long_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-1 In115(n,gamma)In116m Count 1...
# Found data file: Data_CH0@V1725_292_Indium1_90deg_short_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/Indium1_90deg_short_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-1 In115(n,gamma)In116m Count 2...
# Found data file: Data_CH0@V1725_292_Indium1_90deg_long_count2.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/Indium1_90deg_long_count2_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-2 In115(n,n')In115m Count 1...
# Found data file: Data_CH0@V1725_292_Indium2_under_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/Indium2_under_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-2 In115(n,gamma)In116m Count 1...
# Found data file: Data_CH0@V1725_292_Indium2_under_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/Indium2_under_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-3 In115(n,n')In115m Count 1...
# Found data file: Data_CH0@V1725_292_Indium3_180deg_short_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/Indium3_180deg_short_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Indium-3 In115(n,gamma)In116m Count 1...
# Found data file: Data_CH0@V1725_292_Indium3_180deg_short_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/Indium3_180deg_short_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Titanium-1 Ti48(n,p)Sc48 Count 1...
# Found data file: Data_CH0@V1725_292_Titanium_270deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Titanium_270deg_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Titanium_270deg_count1/Titanium_270deg_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Nickel-1 Ni58(n,p)Co58 Count 1...
# Found data file: Data_CH0@V1725_292_Nickel1_under_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Nickel1_under_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Nickel1_under_count1/Nickel1_under_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Molybdenum-1 Mo92(n,p)Nb92m Count 1...
# Found data file: Data_CH0@V1725_292_Molybdenum_270deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Molybdenum_270deg_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Molybdenum_270deg_count1/Molybdenum_270deg_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Processing Niobium-12 Nb93(n,2n)Nb92m Count 1...
# Found data file: Data_CH0@V1725_292_Niobium12_120deg_count1.CSV
# Hello world from get_start_stop_time!
# Looking for run.info file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Niobium12_120deg_count1/run.info
# Looking for info.txt file at ../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Niobium12_120deg_count1/Niobium12_120deg_count1_info.txt
# Found settings.xml file. Using energy bins from file: 16384
# Saving processed measurements to h5 file for future use...
#  ../../data HPGe_activation_data.h5
# Saving measurements to ../../data/HPGe_activation_data.h5...

# %% [markdown]
# ## Energy Calibration
#
# Using gamma check sources like Co-60 and Cs-137, the characteristic photon peaks from these sources are used to convert the digitizer channel bins into energy (keV) bins

# %%
peak_kwargs = {"Na22": {"start_index": 1000, "relative_height": 0.1, "relative_prominence": 0.1}}

# %%
import matplotlib.pyplot as plt
from libra_toolbox.neutron_detection.activation_foils import compass
import scipy
print("Scipy version:", scipy.__version__)
from scipy.signal import find_peaks

calibration_channels = {}
calibration_energies = {}
for name, measurement in check_source_measurements.items():
    fig, ax = plt.subplots(nrows=1, ncols=len(measurement.detectors), figsize=(5 * len(measurement.detectors), 3))
    if not isinstance(ax, np.ndarray):
        ax = [ax]
    for d,detector in enumerate(measurement.detectors):
        if detector.channel_nb not in calibration_channels:
            calibration_channels[detector.channel_nb] = []
            calibration_energies[detector.channel_nb] = []
        hist, bin_edges = detector.get_energy_hist()
        ax[d].stairs(
            hist, 
            bin_edges,
            label=f"Ch {detector.channel_nb}",
        )

        # if peak_kwargs:
        #     print("Scipy peak kwargs:")
        #     for k, v in peak_kwargs.items():
        #         print(f"  {k}: {v}")
        #     scipy_peak_inds, _ = find_peaks(hist[peak_kwargs["start_index"]:],
        #                                     prominence=peak_kwargs['prominence'],
        #                                     height=peak_kwargs['height'],
        #                                     distance=peak_kwargs['distance'],
        #                                     width=peak_kwargs['width'] if 'width' in peak_kwargs else None)
        #     scipy_peak_inds += peak_kwargs["start_index"]
            # peaks_ind = measurement.get_peaks(hist, **peak_kwargs)
        if "Na22" in measurement.name and "Na22" in peak_kwargs:
            peaks_ind = measurement.get_peaks(hist, **peak_kwargs["Na22"])
        else:
            peaks_ind = measurement.get_peaks(hist)
        peaks = bin_edges[peaks_ind]

        # if peak_kwargs:
        #     ax[d].vlines(bin_edges[peak_kwargs["start_index"]], 0, 1.1 * np.max(hist), 
        #                 colors='g', linestyles='dashed',
        #                 alpha=0.8, linewidth=1.0,
        #                 label='Cutoff')
        #     ax[d].vlines(bin_edges[scipy_peak_inds], 0, 1.1 * np.max(hist),
        #                 colors='m', linestyles='dashed',
        #                 alpha=0.8, linewidth=1.0,
        #                 label='SciPy Peaks')

        ax[d].vlines(peaks, 0, 1.1 * np.max(hist), 
                    colors='r', linestyles='dashed',
                    alpha=0.8, linewidth=1.0,
                    label='Peaks')
        
        ax[d].legend()
        ax[d].set_yscale("linear")
        ax[d].set_ylim(top=1.1 * np.max(hist))
        ax[d].set_title(f"{measurement.name} - {detector.channel_nb}")
        ax[d].set_xlabel("Energy Channel")
        ax[d].set_ylabel("Counts")
        if "Ba133" in measurement.name:
            ax[d].set_xlim(0, bin_edges[peaks_ind[-1] + 10] * 1.5)
        # ax[d].set_xlim(0, bin_edges[scipy_peak_inds[-1] + 10] * 1.5)

        if len(peaks) != len(measurement.check_source.nuclide.energy):
            print(f"Peaks found: {peaks}, expected: {measurement.check_source.nuclide.energy}")
            raise ValueError(
                f"SciPy find_peaks() found {len(peaks)} photon peaks, while {len(measurement.check_source.nuclide.energy)} were expected"
            )
        calibration_channels[detector.channel_nb] += list(peaks)
        calibration_energies[detector.channel_nb] += measurement.check_source.nuclide.energy

    fig.tight_layout()

for ch in calibration_channels.keys():
    inds = np.argsort(calibration_channels[ch])
    calibration_channels[ch] = np.array(calibration_channels[ch])[inds]
    calibration_energies[ch] = np.array(calibration_energies[ch])[inds]

plt.show()
# Out:
# Scipy version: 1.16.0
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values

# %%
calibration_channels = {}
calibration_energies = {}
for ch in [0]:
    calibration_channels[ch], calibration_energies[ch] = compass.get_calibration_data(check_source_measurements=check_source_measurements.values(),
                                                                                     background_measurement=background_meas,
                                                                                     channel_nb=ch,
                                                                                     peak_kwargs=peak_kwargs)
    print("Calibration channels:", calibration_channels[ch])
    print("Calibration energies:", calibration_energies[ch])
# Out:
# kwargs provided, updating peak finding parameters with provided values
# kwargs provided, updating peak finding parameters with provided values
# Calibration channels: [1797 1800 1973 1973 2321 2323 2503 2506 3342 3343 4335 4339 5518 5520
#  7787 7788 8473 8473 8870 8871]
# Calibration energies: [ 276.3989  276.3989  302.8508  302.8508  356.0129  356.0129  383.8485
#   383.8485  511.      511.      661.657   661.657   834.848   834.848
#  1173.228  1173.228  1274.537  1274.537  1332.492  1332.492 ]

# %%
calibration_coeffs = {}

for channel_nb in [0]:


    coeff = np.polyfit(calibration_channels[channel_nb], calibration_energies[channel_nb], 1)
    calibration_coeffs[channel_nb] = coeff

    xs = np.linspace(
        calibration_channels[channel_nb][0],
        calibration_channels[channel_nb][-1],
    )
    plt.plot(
        xs,
        np.polyval(coeff, xs),
        label=f"Ch {channel_nb} fit",
    )
    plt.scatter(
        calibration_channels[channel_nb],
        calibration_energies[channel_nb],
        label=f"Ch {channel_nb} data",
        alpha=0.5,
    )
plt.xlabel("Channel number")
plt.ylabel("Energy (keV)")
plt.legend()
#change figure size
plt.gcf().set_size_inches(9 * len(calibration_channels), 4)
plt.show()

# %% [markdown]
# ## Detector Efficiency
#
# Using these same check-sources, each with a known activity, an efficiency curve for each detector is calculated.
#
# Two types of efficiency curves are shown:
# 1. Exponent of sum of logarithms (used in https://doi.org/10.2172/1524045): $ y = \exp(\sum_{i=0}^n a_n \log(E)^i) $
#
# 2. Polynomial fit (3rd order): $ y = \sum_{i=0}^n a_n E^i $
#
# **Only the polynomal fit is currently implemented in libra-toolbox, so that is the curve that will be used to calculate the efficiency of the detectors at measuring the activity of the activation foil peaks.**

# %% [markdown]
# ## Bayesian Model with Preset Function

# %% [markdown]
# ## Why Find the Peak of the Posterior Probability Distribution?
#
# The **Maximum A Posteriori (MAP)** method finds the peak of the posterior probability distribution because **this peak represents the parameter values that are most consistent with both your data AND your prior knowledge**.
#
# ### The Intuitive Explanation
#
# Imagine you're trying to estimate the efficiency parameters for your detector. You have:
#
# 1. **Your measured data**: Efficiency measurements at different energies (with uncertainties)
# 2. **Your prior knowledge**: Physical intuition about what reasonable parameter values should be
#
# The posterior probability tells you: *"Given my prior beliefs and the data I just collected, how likely is each possible set of parameter values?"*
#
# - **High probability** = These parameter values make sense given both physics and data
# - **Low probability** = These parameter values either contradict the data or seem physically unreasonable
#
# **The peak is where these two sources of information agree most strongly.**
#
# ### Why Not Just Fit the Data Without Priors?
#
# Without priors (pure maximum likelihood), you might get:
# - Parameter values that fit the data perfectly but are physically unrealistic
# - Overfitting to noise in your measurements
# - Unstable results when you have limited data points
#
# ### Why Not Just Use Prior Knowledge Without Data?
#
# Without considering the data, you'd just be guessing based on theory - you wouldn't learn anything from your actual measurements!
#
# ### The MAP Sweet Spot
#
# The MAP estimate finds the **optimal balance** between:
# - **Fitting your data well** (high likelihood)
# - **Staying within reasonable bounds** (respecting priors)
#
# ### Real-World Example
#
# In your efficiency fitting:
# - Your **data** says: "At 600 keV, efficiency was 0.021 ± 0.0006"
# - Your **prior** says: "Based on physics, I expect a₀ ≈ -2, a₁ ≈ 0.5"
# - The **MAP** finds: "The parameters that best satisfy BOTH constraints simultaneously"
#
# ### What the Peak Tells You
#
# The peak represents the **most credible parameter values** - if you had to make your best single guess about the true parameters, this would be it.
#
# The **width of the peak** (which we estimate with the Hessian) tells you how confident you can be in this estimate:
# - **Narrow peak** = High confidence, well-constrained parameters
# - **Broad peak** = Lower confidence, parameters could vary more
#
# This is why MAP is so powerful for scientific applications - it gives you both the best estimate AND a measure of how reliable that estimate is!

# %%
def eff_curve_func(E, *a):
    exponent_term = 0
    for i,a_n in enumerate(a):
        exponent_term += a_n * (np.log(E) ** i)
    return np.exp(exponent_term)

# %% [markdown]
# ### The MAP Balancing Act
#
# The key insight is that **finding the peak of the posterior probability distribution gives you the parameter values that represent the best compromise between your prior knowledge and your data**.
#
# Here's why this matters specifically for your efficiency measurements:
#
# #### The Three Alternatives and Their Problems:
#
# 1. **Pure Data Fitting (Maximum Likelihood Only)**
#    - Problem: Might give physically unrealistic parameters
#    - Example: Could suggest efficiency increases with energy (violates physics)
#
# 2. **Pure Prior Knowledge (Ignore Data)**
#    - Problem: You learn nothing from your expensive measurements!
#    - Example: Just assume efficiency follows some textbook curve
#
# 3. **Arbitrary Weighting**
#    - Problem: How much should you trust data vs. prior knowledge?
#    - Example: "I'll trust the data 70% and my prior 30%" - but why those numbers?
#
# #### The MAP Solution:
#
# The MAP method **automatically finds the optimal balance** using probability theory. The peak occurs where:
#
# ```
# P(parameters | data, prior) ∝ P(data | parameters) × P(parameters)
#                                     ↑                    ↑
#                                Likelihood              Prior
# ```
#
# - If your **data is very precise** (small error bars), the likelihood dominates → MAP trusts data more
# - If your **data is noisy** (large error bars), the prior has more influence → MAP stays closer to physics intuition
# - If your **prior is very certain** (narrow distribution), it constrains the result more
# - If your **prior is vague** (wide distribution), the data drives the result
#
# #### In Your Specific Case:
#
# When you fit detector efficiency vs energy:
# - **Data says**: "Here are my measured efficiencies with their uncertainties"
# - **Prior says**: "Physics suggests a₀ should be around -2 (log-scale efficiency), a₁ should be positive (efficiency decreases with energy)"
# - **MAP finds**: The parameter values that best satisfy both simultaneously
#
# The peak represents the **most defensible scientific estimate** - it's the set of parameters you'd report in a paper because they're both consistent with your measurements AND physically reasonable.
#
# The beauty of MAP is that it does this balancing act **objectively** using probability theory, rather than requiring you to make subjective judgments about how much to weight different sources of information.

# %%
from scipy.optimize import curve_fit
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import (
    ConstantKernel, Matern, RationalQuadratic, RBF
)

channels = []
efficiency_coeffs = {}

efficiency_dict = {}
efficiency_err_dict = {}
energy_dict = {}

measurement = list(check_source_measurements.values())[0]
search_width = 10
threshold_overlap = 10

for detector in measurement.detectors:
    channels.append(detector.channel_nb)

fig, ax = plt.subplots(nrows=1, ncols=len(channels), figsize=(12, 6))
if len(channels) == 1:
    ax = [ax]
for i,ch in enumerate(channels):
    background_detector = background_meas.get_detector(ch)
    energies = []
    efficiencies = []
    eff_errs = []
    for name, measurement in check_source_measurements.items():
        check_source_detector = measurement.get_detector(ch)
        hist, bin_edges = check_source_detector.get_energy_hist_background_substract(background_detector)
        calibrated_bin_edges = np.polyval(calibration_coeffs[ch], bin_edges)
        fig_1, ax_1 = plt.subplots()
        ax_1.stairs(hist, calibrated_bin_edges)
        ax_1.set_title(f"{name} - Ch {ch}")
        ax_1.set_xlabel("Energy (keV)")
        ax_1.set_ylabel("Counts")

        print("measurement._uncalibrated_measured_energies:", measurement._uncalibrated_measured_energies[ch])
        peak_energies = measurement.get_calibrated_measured_energies(ch,
                                                                     calibration_coeffs=calibration_coeffs[ch])
        ax_1.set_xlim(peak_energies[0] * 0.8, peak_energies[-1] * 1.2)
        ax_1.set_yscale('log')
        
        efficiency, eff_err = measurement.compute_detection_efficiency(
            background_measurement=background_meas,
            calibration_coeffs=calibration_coeffs[ch],
            channel_nb=ch,
            search_width=search_width,
            compute_error=True,
            threshold_overlap=threshold_overlap,
            ax=ax_1
        )
        print(f"{name} Ch {ch}: Efficiency = {efficiency} +/- {eff_err}")

        energies += measurement.check_source.nuclide.energy
        efficiencies += list(efficiency)
        eff_errs += list(eff_err)
        ax[i].errorbar(
            measurement.check_source.nuclide.energy,
            efficiency * 100,
            yerr=eff_err * 100,
            label=name,
            fmt="o",
        )

    # Sort energies and efficiencies for fitting
    sorted_indices = np.argsort(energies)
    energies = np.array(energies)[sorted_indices]
    efficiencies = np.array(efficiencies)[sorted_indices]
    eff_errs = np.array(eff_errs)[sorted_indices]

    energy_dict[ch] = energies
    efficiency_dict[ch] = efficiencies
    efficiency_err_dict[ch] = eff_errs
    
    print(f"Ch {ch} \n\t Energies: {energies}, \n\t Efficiencies: {efficiencies}")

    # Fit the efficiency curve

    poly_coeff = np.polyfit(energies, efficiencies, 3)
    efficiency_coeffs[ch] = poly_coeff
    xs = np.linspace(
        energies[0],
        energies[-1],
        100,
    )

    ax[i].plot(
        xs,
        np.polyval(poly_coeff, xs) * 100,
        label="Polyfit efficiency curve",
    )
    ax[i].set_xlabel("Energy (keV)")
    ax[i].set_ylabel("Detection efficiency (%)")
    ax[i].set_title(f"Channel {ch}")
    ax[i].legend()
    # plt.ylim(bottom=0)

plt.show()
# Out:
# measurement._uncalibrated_measured_energies: [np.int64(1800), np.int64(1973), np.int64(2323), np.int64(2506)]
# [278.75111799 304.58292551 356.84380779 384.16878338]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(278.7511179882777)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(304.58292551330686)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(356.84380778937737)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(384.16878337943706)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Ba133 :  [ 1588.94149108  3649.176629   10731.85314542  1447.79140019]
# Ba133 Count 1 Ch 0: Efficiency = [0.00078266 0.00070174 0.00060997 0.00057115] +/- [1.96344574e-05 1.16165211e-05 5.88807791e-06 1.50104410e-05]
# measurement._uncalibrated_measured_energies: [np.int64(1797), np.int64(1973), np.int64(2321), np.int64(2503)]
# [278.30316757 304.58292551 356.54517418 383.72083296]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(278.3031675687685)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(304.58292551330686)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(356.54517417637123)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(383.7208329599279)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Ba133 :  [ 3750.31982996  8968.04165985 26113.08174545  3502.66084269]
# Ba133 Count 2 Ch 0: Efficiency = [0.00082094 0.0007664  0.00065959 0.00061407] +/- [1.34053513e-05 8.09294423e-06 4.08173071e-06 1.03757284e-05]
# measurement._uncalibrated_measured_energies: [np.int64(7787), np.int64(8870)]
# [1172.71083852 1334.42093996]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(1172.7108385220897)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(1334.4209399649021)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Co60 :  [1904.98084697 1689.26072536]
# Co60 Count 1 Ch 0: Efficiency = [0.00019393 0.00017174] +/- [4.44316346e-06 4.17848617e-06]
# measurement._uncalibrated_measured_energies: [np.int64(7788), np.int64(8871)]
# [1172.86015533 1334.57025677]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(1172.8601553285928)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(1334.5702567714052)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Co60 :  [2466.58555781 2210.03132627]
# Co60 Count 2 Ch 0: Efficiency = [0.00020356 0.00018214] +/- [4.09865596e-06 3.87450505e-06]
# measurement._uncalibrated_measured_energies: [np.int64(4339)]
# [657.8664897]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Cs137 :  [13902.36911958]
# Cs137 Count 1 Ch 0: Efficiency = [0.00033415] +/- [2.83398498e-06]
# measurement._uncalibrated_measured_energies: [np.int64(4335)]
# [657.26922247]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Cs137 :  [14628.46336763]
# Cs137 Count 2 Ch 0: Efficiency = [0.00035185] +/- [2.90912025e-06]
# measurement._uncalibrated_measured_energies: [np.int64(3342), np.int64(8473)]
# [ 508.99763362 1275.14216778]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(508.99763361599406)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(1275.142167783188)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Na22 :  [19131.13467347  4947.47820676]
# Na22 Count 1 Ch 0: Efficiency = [0.00037014 0.0001724 ] +/- [2.67607831e-06 2.45105783e-06]
# measurement._uncalibrated_measured_energies: [np.int64(3343), np.int64(8473)]
# [ 509.14695042 1275.14216778]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [np.float64(509.1469504224971)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [np.float64(1275.142167783188)]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Na22 :  [23550.49752396  5021.41084977]
# Na22 Count 2 Ch 0: Efficiency = [0.00045667 0.00017537] +/- [2.97577393e-06 2.47483318e-06]
# measurement._uncalibrated_measured_energies: [np.int64(5520)]
# [834.20963818]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Mn54 :  [161.9776371]
# Mn54 Count 1 Ch 0: Efficiency = [0.00025821] +/- [2.02881001e-05]
# measurement._uncalibrated_measured_energies: [np.int64(5518)]
# [833.91100457]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Measured counts under peaks for  Mn54 :  [421.40055594]
# Mn54 Count 2 Ch 0: Efficiency = [0.00028087] +/- [1.36821295e-05]
# Ch 0
# 	 Energies: [ 276.3989  276.3989  302.8508  302.8508  356.0129  356.0129  383.8485
#   383.8485  511.      511.      661.657   661.657   834.848   834.848
#  1173.228  1173.228  1274.537  1274.537  1332.492  1332.492 ],
# 	 Efficiencies: [0.00078266 0.00082094 0.0007664  0.00070174 0.00065959 0.00060997
#  0.00057115 0.00061407 0.00037014 0.00045667 0.00035185 0.00033415
#  0.00025821 0.00028087 0.00020356 0.00019393 0.0001724  0.00017537
#  0.00017174 0.00018214]

# %%
# Simplified Bayesian-style fitting without PyMC compilation issues
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize, differential_evolution
from scipy.stats import multivariate_normal
import warnings
warnings.filterwarnings('ignore')

def negative_log_posterior(params, energies, efficiencies, eff_errs):
    """Negative log posterior for optimization"""
    a0, a1, a2, a3 = params
    
    # Priors (log normal distributions)
    log_prior = 0
    log_prior += -0.5 * ((a0 - (-2.0))/2.0)**2  # Prior centered at -2
    log_prior += -0.5 * ((a1 - 0.5)/1.0)**2     # Prior centered at 0.5  
    log_prior += -0.5 * ((a2 - 0.0)/0.5)**2     # Prior centered at 0
    log_prior += -0.5 * ((a3 - 0.0)/0.1)**2     # Prior centered at 0
    
    # Likelihood
    try:
        model_pred = eff_curve_func(energies, a0, a1, a2, a3)
        if np.any(np.isnan(model_pred)) or np.any(np.isinf(model_pred)) or np.any(model_pred <= 0):
            return 1e10
        residuals = (efficiencies - model_pred) / eff_errs
        log_likelihood = -0.5 * np.sum(residuals**2)
    except:
        return 1e10
    
    return -(log_prior + log_likelihood)

map_results = {}
# Process each channel
for ch in energy_dict.keys():
    print(f"\nProcessing Channel {ch}")
    
    energies = energy_dict[ch]
    efficiencies = efficiency_dict[ch]
    eff_errs = efficiency_err_dict[ch]
    
    # Find MAP (Maximum A Posteriori) estimate
    bounds = [(-10, 5), (-2, 3), (-1, 1), (-0.5, 0.5)]  # Reasonable bounds
    
    # Use differential evolution for global optimization
    result = differential_evolution(
        negative_log_posterior, 
        bounds, 
        args=(energies, efficiencies, eff_errs),
        seed=42,
        maxiter=1000,
        tol=1e-6
    )
    
    if result.success:
        map_params = result.x
        print(f"MAP estimate: a0={map_params[0]:.3f}, a1={map_params[1]:.3f}, a2={map_params[2]:.3f}, a3={map_params[3]:.3f}")
        
        # Estimate uncertainty using Hessian approximation
        from scipy.optimize import approx_fprime
        
        def neg_log_post_wrapper(params):
            return negative_log_posterior(params, energies, efficiencies, eff_errs)
        
        # Approximate the Hessian at MAP
        eps = 1e-5
        hess_diag = []
        for i in range(4):
            params_plus = map_params.copy()
            params_minus = map_params.copy()
            params_plus[i] += eps
            params_minus[i] -= eps
            
            second_deriv = (neg_log_post_wrapper(params_plus) - 
                          2*neg_log_post_wrapper(map_params) + 
                          neg_log_post_wrapper(params_minus)) / eps**2
            hess_diag.append(max(second_deriv, 1e-6))  # Ensure positive
        
        # Parameter uncertainties (diagonal approximation)
        param_stds = 1.0 / np.sqrt(np.array(hess_diag))
        
        print(f"Parameter uncertainties: ±{param_stds[0]:.3f}, ±{param_stds[1]:.3f}, ±{param_stds[2]:.5f}, ±{param_stds[3]:.5f}")
        
        # Store MAP results for later use
        map_results[ch] = {
            'params': map_params,
            'uncertainties': param_stds,
            'energy_range': (energies.min(), energies.max())
        }
        
        # Generate samples from approximate posterior (multivariate normal)
        cov_matrix = np.diag(param_stds**2)
        n_samples = 1000
        posterior_samples = multivariate_normal.rvs(
            mean=map_params, 
            cov=cov_matrix, 
            size=n_samples,
            random_state=42
        )
        
        # Plot results
        plt.figure(figsize=(10, 5))

        # Calculate y-offset for labels based on data range
        eff_range = np.max(efficiencies) - np.min(efficiencies)
        y_offset = eff_range * 0.08  # 8% of the range
        
        # Track which sources have been labeled to avoid duplicates
        labeled_sources = set()
        
        # Plot data
        for i,data_i in enumerate(zip(energies, efficiencies, eff_errs)):
            energy, efficiency, eff_err = data_i
            if 200 < energy < 400:
                source_label = "Ba-133"
                source_color = 'orange'
            elif 500 < energy < 520:
                source_label = 'Na-22'
                source_color = 'tab:blue'
            elif 600 < energy < 700:
                source_label = 'Cs-137'
                source_color = 'purple'
            elif 800 < energy < 900:
                source_label = 'Mn-54'
                source_color = 'gray'
            elif 1100 < energy < 1200:
                source_label = 'Co-60'
                source_color = 'green'
            elif 1200 < energy < 1300:
                source_label = "Na-22"
                source_color = 'tab:blue'
            elif 1300 < energy < 1400:
                source_label = 'Co-60'
                source_color = 'green'
            else:
                source_label = 'Other'
                source_color = 'gray'
            if i==0:
                plot_label = "Measured"
            else:
                plot_label = None
            plt.errorbar(energy, efficiency, yerr=eff_err, fmt='o', label=plot_label, 
                         color=source_color, capsize=3, markersize=6)
            
            # Only label each source once, and use relative offset
            if source_label not in labeled_sources:
                # Alternate above/below to reduce overlap
                sign = 1 if len(labeled_sources) % 2 == 0 else -1
                plt.text(energy, efficiency + sign * (eff_err + y_offset), source_label, 
                        color=source_color, fontsize=10, ha='center', va='bottom' if sign > 0 else 'top')
                labeled_sources.add(source_label)

        # Plot MAP fit
        xs = np.linspace(energies.min(), energies.max(), 200)
        map_curve = eff_curve_func(xs, *map_params)
        plt.plot(xs, map_curve, 'r-', linewidth=2, label='MAP fit')
        
        # Plot uncertainty band using posterior samples
        curves = []
        for i in range(0, min(200, len(posterior_samples)), 5):
            try:
                curve = eff_curve_func(xs, *posterior_samples[i])
                if np.all(np.isfinite(curve)) and np.all(curve > 0):
                    curves.append(curve)
                    if len(curves) <= 20:  # Only plot first 20 for visibility
                        plt.plot(xs, curve, 'gray', alpha=0.1, linewidth=0.5)
            except:
                continue
        
        # Calculate credible interval
        if curves:
            curves = np.array(curves)
            lower = np.percentile(curves, 2.5, axis=0)
            upper = np.percentile(curves, 97.5, axis=0)
            plt.fill_between(xs, lower, upper, alpha=0.3, color='red', 
                           label='95% Credible Interval')
        
        plt.xlabel('Energy (keV)', fontsize=12)
        plt.ylabel('Efficiency', fontsize=12)
        plt.title(f'MAP Efficiency Fit - Channel {ch}', fontsize=16)
        plt.legend()
        plt.grid(True, alpha=0.3)
        plt.ylim(0.000, np.max(efficiencies)*1.2)
        plt.savefig(f'efficiency_fit_channel_{ch}.png', dpi=300)
        plt.show()
        
        # Summary statistics
        print(f"\nPosterior Summary for Channel {ch}:")
        param_names = ['a0', 'a1', 'a2', 'a3']
        print(f"{'Parameter':<10} {'Mean':<10} {'Std':<10} {'2.5%':<10} {'97.5%':<10}")
        print("-" * 50)
        for i, name in enumerate(param_names):
            samples_i = posterior_samples[:, i]
            mean_val = np.mean(samples_i)
            std_val = np.std(samples_i)
            q025 = np.percentile(samples_i, 2.5)
            q975 = np.percentile(samples_i, 97.5)
            print(f"{name:<10} {mean_val:<10.3f} {std_val:<10.3f} {q025:<10.3f} {q975:<10.3f}")
    
    else:
        print(f"Optimization failed for channel {ch}")
        print("Falling back to simple curve_fit...")
        
        # Fallback to scipy curve_fit
        from scipy.optimize import curve_fit
        try:
            popt, pcov = curve_fit(eff_curve_func, energies, efficiencies, 
                                 sigma=eff_errs, p0=[-2, 0.5, 0, 0])
            param_errs = np.sqrt(np.diag(pcov))
            
            plt.figure(figsize=(10, 6))
            plt.errorbar(energies, efficiencies, yerr=eff_errs, fmt='o', 
                        label='Data', capsize=3)
            xs = np.linspace(energies.min(), energies.max(), 200)
            plt.plot(xs, eff_curve_func(xs, *popt), 'r-', linewidth=2, 
                    label='Curve fit')
            plt.xlabel('Energy (keV)')
            plt.ylabel('Efficiency')
            plt.ylim(0.005, np.max(efficiencies)*1.2)
            plt.title(f'Fallback Curve Fit - Channel {ch}')
            plt.legend()
            plt.show()
            
            print(f"Fitted parameters: a0={popt[0]:.3f}±{param_errs[0]:.3f}, "
                  f"a1={popt[1]:.3f}±{param_errs[1]:.3f}, "
                  f"a2={popt[2]:.3f}±{param_errs[2]:.3f}, "
                  f"a3={popt[3]:.3f}±{param_errs[3]:.3f}")
        except Exception as e:
            print(f"Even curve_fit failed: {e}")

print("\nBayesian-style fitting complete!")
# Out:
# Processing Channel 0
# MAP estimate: a0=-1.834, a1=-0.205, a2=-0.224, a3=0.017
# Parameter uncertainties: ±0.003, ±0.000, ±0.00007, ±0.00001
# Posterior Summary for Channel 0:
# Parameter  Mean       Std        2.5%       97.5%
# --------------------------------------------------
# a0         -1.834     0.002      -1.839     -1.829
# a1         -0.205     0.000      -0.206     -0.204
# a2         -0.224     0.000      -0.224     -0.224
# a3         0.017      0.000      0.017      0.017
#
# Bayesian-style fitting complete!

# %%
# Function to calculate efficiency and uncertainty at arbitrary energies
def calculate_efficiency_at_energy(energy, channel, method='propagation'):
    """
    Calculate efficiency and 1-sigma uncertainty at a given energy using MAP results
    
    Parameters:
    -----------
    energy : float or array
        Energy value(s) in keV where you want to calculate efficiency
    channel : int 
        Channel number (4 or 5)
    method : str
        'propagation' for analytical uncertainty propagation
        'sampling' for Monte Carlo sampling approach
        
    Returns:
    --------
    efficiency : float or array
        Predicted efficiency value(s)
    uncertainty : float or array  
        1-sigma uncertainty in efficiency
    """
    
    # Check if we have MAP results for this channel
    if channel not in map_results:
        raise ValueError(f"No MAP results available for channel {channel}. Run the Bayesian fitting first.")
    
    map_params = map_results[channel]['params']
    param_stds = map_results[channel]['uncertainties']
    
    # Convert energy to array for consistent handling
    energy = np.atleast_1d(energy)
    
    # Calculate efficiency using MAP parameters
    efficiency = eff_curve_func(energy, *map_params)
    
    if method == 'propagation':
        # Analytical uncertainty propagation using partial derivatives
        # For f(E) = exp(a0 + a1*ln(E) + a2*ln(E)^2 + a3*ln(E)^3)
        # df/da_i = f(E) * ln(E)^i
        
        log_E = np.log(energy)
        
        # Partial derivatives
        df_da0 = efficiency  # df/da0 = f(E)
        df_da1 = efficiency * log_E  # df/da1 = f(E) * ln(E)
        df_da2 = efficiency * log_E**2  # df/da2 = f(E) * ln(E)^2  
        df_da3 = efficiency * log_E**3  # df/da3 = f(E) * ln(E)^3
        
        # Uncertainty propagation: sigma_f^2 = sum((df/da_i)^2 * sigma_a_i^2)
        uncertainty_squared = (
            (df_da0 * param_stds[0])**2 + 
            (df_da1 * param_stds[1])**2 + 
            (df_da2 * param_stds[2])**2 + 
            (df_da3 * param_stds[3])**2
        )
        uncertainty = np.sqrt(uncertainty_squared)
        
    elif method == 'sampling':
        # Monte Carlo sampling approach
        n_samples = 1000
        cov_matrix = np.diag(param_stds**2)
        
        # Generate parameter samples
        param_samples = np.random.multivariate_normal(
            map_params, cov_matrix, size=n_samples
        )
        
        # Calculate efficiency for each parameter sample
        efficiency_samples = []
        for params in param_samples:
            try:
                eff_sample = eff_curve_func(energy, *params)
                if np.all(np.isfinite(eff_sample)) and np.all(eff_sample > 0):
                    efficiency_samples.append(eff_sample)
            except:
                continue
                
        if efficiency_samples:
            efficiency_samples = np.array(efficiency_samples)
            # Use the mean and std of samples
            efficiency = np.mean(efficiency_samples, axis=0)
            uncertainty = np.std(efficiency_samples, axis=0)
        else:
            # Fallback to propagation method
            return calculate_efficiency_at_energy(energy, channel, method='propagation')
    
    # Return scalar if input was scalar
    if len(energy) == 1:
        return float(efficiency[0]), float(uncertainty[0])
    else:
        return efficiency, uncertainty


print("Efficiency calculation function defined. Run the Bayesian fitting to populate map_results.")
# Out:
# Efficiency calculation function defined. Run the Bayesian fitting to populate map_results.

# %% [markdown]
# ## Uncertainty Quantification: Propagation vs. Sampling
#
# The `calculate_efficiency_at_energy()` function offers two methods for estimating uncertainties. Here's a detailed comparison:
#
# ### Method 1: Analytical Error Propagation ('propagation')
#
# **How it works:**
# - Uses partial derivatives to compute how uncertainties in parameters translate to uncertainties in predictions
# - Formula: `σ_f² = Σ(∂f/∂a_i)² × σ_a_i²`
# - For our efficiency function: `f(E) = exp(a₀ + a₁ln(E) + a₂ln²(E) + a₃ln³(E))`
#
# **Pros:**
# - **Fast**: Analytical calculation, no Monte Carlo sampling needed
# - **Exact**: Gives the mathematically correct uncertainty (for linear approximation)
# - **Deterministic**: Always gives the same result
# - **Memory efficient**: No need to store thousands of samples
# - **Good for real-time applications**: Instant results
#
# **Cons:**
# - **Linear approximation**: Only accurate when the function is approximately linear near the MAP estimate
# - **Assumes Gaussian uncertainties**: May underestimate uncertainties if parameter distributions are non-Gaussian
# - **No correlation information**: Our implementation assumes parameters are uncorrelated
# - **Can fail for highly nonlinear functions**: May give poor estimates if efficiency function has strong curvature
#
# **Best for:** Most routine calculations, when you need fast results, when parameter uncertainties are small relative to the function's curvature.
#
# ### Method 2: Monte Carlo Sampling ('sampling')
#
# **How it works:**
# - Generates many random parameter sets from the posterior distribution
# - Calculates efficiency for each parameter set
# - Uses the standard deviation of these predictions as the uncertainty estimate
#
# **Pros:**
# - **Handles nonlinearity**: Captures the true uncertainty even for highly nonlinear functions
# - **No mathematical approximations**: Directly samples from the posterior
# - **Captures asymmetric uncertainties**: Can detect if uncertainty is larger in one direction
# - **Can include correlations**: Easy to extend to include parameter correlations
# - **Robust**: Works for any function, no matter how complex
#
# **Cons:**
# - **Slower**: Requires generating and evaluating many samples (typically 1000+)
# - **Stochastic**: Results vary slightly between runs due to random sampling
# - **Memory intensive**: Must store parameter samples
# - **Assumes correct posterior approximation**: Only as good as your parameter uncertainty estimates
#
# **Best for:** When you suspect strong nonlinearities, want to capture asymmetric uncertainties, or need the most robust uncertainty estimate.
#
# ### When to Use Which Method?
#
# **Use Propagation when:**
# - You need fast, routine calculations
# - Parameter uncertainties are small (< 10% of parameter values)
# - The efficiency function is reasonably smooth and linear locally
# - You're doing many repeated calculations
#
# **Use Sampling when:**
# - You want the most robust uncertainty estimate
# - You suspect the efficiency function has strong curvature
# - Parameter uncertainties are large
# - You're doing a final, high-precision analysis
# - You want to check if propagation results are reliable
#
# ### For Your Efficiency Curves:
#
# In your case, the efficiency function `exp(a₀ + a₁ln(E) + ...)` is moderately nonlinear, but your MAP parameter uncertainties are quite small (σ ~ 0.01 for most parameters). This suggests:
#
# - **Propagation should be quite accurate** for most purposes
# - **Sampling provides a good cross-check** to verify propagation results
# - **Both methods should give similar results** if the linear approximation is valid
#
# ### Quick Comparison Test:
#
# You can easily compare both methods as shown below.  If the difference is < 5%, propagation is likely sufficient. If > 20%, the nonlinearity is significant and sampling is more trustworthy.

# %%
# Compare methods for a specific energy
energy = 900  # keV
eff_prop, unc_prop = calculate_efficiency_at_energy(energy, 0, method='propagation')
eff_samp, unc_samp = calculate_efficiency_at_energy(energy, 0, method='sampling')

print(f"Propagation: {eff_prop:.6f} ± {unc_prop:.6f}")
print(f"Sampling:    {eff_samp:.6f} ± {unc_samp:.6f}")
print(f"Difference:  {abs(unc_prop - unc_samp)/unc_prop*100:.1f}%")
# Out:
# Propagation: 0.000244 ± 0.000001
# Sampling:    0.000244 ± 0.000001
# Difference:  1.5%

# %%
# Practical comparison of propagation vs. sampling methods
if map_results:  # Only run if we have MAP results
    print("=== COMPARISON: Propagation vs. Sampling Methods ===\n")
    
    # Test energies spanning the fitted range
    test_energies = [600, 750, 900, 1050, 1200]
    
    for ch in map_results.keys():
        print(f"Channel {ch}:")
        print(f"{'Energy (keV)':<12} {'Method':<12} {'Efficiency':<12} {'Uncertainty':<12} {'Rel. Unc. (%)':<12}")
        print("-" * 65)
        
        for energy in test_energies:
            energy_range = map_results[ch]['energy_range']
            if energy_range[0] <= energy <= energy_range[1]:
                
                # Propagation method
                eff_prop, unc_prop = calculate_efficiency_at_energy(energy, ch, method='propagation')
                rel_unc_prop = unc_prop / eff_prop * 100
                
                # Sampling method
                eff_samp, unc_samp = calculate_efficiency_at_energy(energy, ch, method='sampling')
                rel_unc_samp = unc_samp / eff_samp * 100
                
                # Display results
                print(f"{energy:<12.0f} {'Propagation':<12} {eff_prop:<12.6f} {unc_prop:<12.6f} {rel_unc_prop:<12.1f}")
                print(f"{'':<12} {'Sampling':<12} {eff_samp:<12.6f} {unc_samp:<12.6f} {rel_unc_samp:<12.1f}")
                
                # Calculate difference
                unc_diff_pct = abs(unc_prop - unc_samp) / unc_prop * 100
                eff_diff_pct = abs(eff_prop - eff_samp) / eff_prop * 100
                
                print(f"{'':<12} {'Difference':<12} {eff_diff_pct:<11.3f}% {unc_diff_pct:<11.3f}%")
                print()
        
        print()
    
    
    # Summary assessment
    print("=== ASSESSMENT ===")
    print("If the uncertainty bands largely overlap and differences are < 5%:")
    print("→ Propagation method is sufficiently accurate")
    print("\nIf differences are 5-20%:")
    print("→ Moderate nonlinearity present, consider sampling for important calculations")
    print("\nIf differences are > 20%:")
    print("→ Strong nonlinearity, use sampling method for reliable uncertainties")
    
else:
    print("No MAP results available. Please run the Bayesian fitting first.")
# Out:
# === COMPARISON: Propagation vs. Sampling Methods ===
#
# Channel 0:
# Energy (keV) Method       Efficiency   Uncertainty  Rel. Unc. (%)
# -----------------------------------------------------------------
# 600          Propagation  0.000361     0.000002     0.5
#              Sampling     0.000362     0.000002     0.5
#              Difference   0.019      % 0.576      %
#
# 750          Propagation  0.000290     0.000002     0.6
#              Sampling     0.000290     0.000002     0.6
#              Difference   0.003      % 1.594      %
#
# 900          Propagation  0.000244     0.000001     0.6
#              Sampling     0.000244     0.000001     0.6
#              Difference   0.020      % 1.903      %
#
# 1050         Propagation  0.000212     0.000001     0.6
#              Sampling     0.000212     0.000001     0.6
#              Difference   0.003      % 3.034      %
#
# 1200         Propagation  0.000189     0.000001     0.6
#              Sampling     0.000189     0.000001     0.6
#              Difference   0.018      % 2.473      %
#
#
# === ASSESSMENT ===
# If the uncertainty bands largely overlap and differences are < 5%:
# → Propagation method is sufficiently accurate
#
# If differences are 5-20%:
# → Moderate nonlinearity present, consider sampling for important calculations
#
# If differences are > 20%:
# → Strong nonlinearity, use sampling method for reliable uncertainties

# %%
# Example: Calculate efficiency at specific energies
# (Run this after the Bayesian fitting above)

if map_results:  # Only run if we have MAP results
    print("Examples of calculating efficiency at arbitrary energies:\n")
    
    for ch in map_results.keys():
        energy_range = map_results[ch]['energy_range']
        print(f"Channel {ch} (valid range: {energy_range[0]:.0f} - {energy_range[1]:.0f} keV)")
        
        # Example energies within the fitted range
        test_energies = [600, 750, 900, 1000, 1200]
        
        for energy in test_energies:
            if energy_range[0] <= energy <= energy_range[1]:  # Check if within fitted range
                eff, eff_err = calculate_efficiency_at_energy(energy, ch, method='propagation')
                print(f"  At {energy} keV: efficiency = {eff:.6f} ± {eff_err:.6f} ({eff_err/eff*100:.1f}%)")
        
        print()
    
    # Example: Calculate efficiency curve with uncertainties
    print("Plotting efficiency curves with uncertainty bands:")
    
    fig, axes = plt.subplots(1, len(map_results), figsize=(12, 5))
    if len(map_results) == 1:
        axes = [axes]
    
    for i, ch in enumerate(map_results.keys()):
        energy_range = map_results[ch]['energy_range']
        
        # Create fine energy grid
        energy_grid = np.linspace(energy_range[0], energy_range[1], 100)
        
        # Calculate efficiencies and uncertainties
        eff_pred, eff_unc = calculate_efficiency_at_energy(energy_grid, ch, method='propagation')
        
        # Plot original data
        energies = energy_dict[ch]
        efficiencies = efficiency_dict[ch]
        eff_errs = efficiency_err_dict[ch]
        
        axes[i].errorbar(energies, efficiencies, yerr=eff_errs, fmt='o', 
                        label='Data', capsize=3, markersize=6)
        
        # Plot MAP prediction with uncertainty band
        axes[i].plot(energy_grid, eff_pred, 'r-', linewidth=2, label='MAP prediction')
        axes[i].fill_between(energy_grid, 
                            eff_pred - eff_unc, 
                            eff_pred + eff_unc,
                            alpha=0.3, color='red', label='±1σ uncertainty')
        
        axes[i].set_xlabel('Energy (keV)')
        axes[i].set_ylabel('Efficiency')
        axes[i].set_title(f'Channel {ch} - Efficiency Prediction')
        axes[i].legend()
        axes[i].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.show()
    
else:
    print("No MAP results found. Please run the Bayesian fitting cell first.")
# Out:
# Examples of calculating efficiency at arbitrary energies:
#
# Channel 0 (valid range: 276 - 1332 keV)
#   At 600 keV: efficiency = 0.000361 ± 0.000002 (0.5%)
#   At 750 keV: efficiency = 0.000290 ± 0.000002 (0.6%)
#   At 900 keV: efficiency = 0.000244 ± 0.000001 (0.6%)
#   At 1000 keV: efficiency = 0.000222 ± 0.000001 (0.6%)
#   At 1200 keV: efficiency = 0.000189 ± 0.000001 (0.6%)
#
# Plotting efficiency curves with uncertainty bands:

# %% [markdown]
# ## Calculating average neutron rate from activation foils
#
# First, the irradiation schedule and the foil information is collected.

# %%
for name, foil_dict in foil_measurements.items():
    print(f"Foil: {name}")
    print(foil_dict)
    for meas_name, measurement in foil_dict["measurements"].items():
        print(f"  Measurement: {meas_name}")
        for det in measurement.detectors:
            # hist, bin_edges = det.get_energy_hist_background_substract(background_meas.get_detector(det.channel_nb))
            # calibrated_bin_edges = np.polyval(calibration_coeffs[det.channel_nb], bin_edges)
            # plt.figure()
            # plt.stairs(hist, calibrated_bin_edges)
            # plt.title(f"{name} - {meas_name} - Ch {det.channel_nb}")
            # plt.xlabel("Energy (keV)")
            # plt.ylabel("Counts")
            # # plt.yscale('log')
            # plt.show()
            fig, ax, all_fit_params = compass.plot_histogram_with_peak_fit(det,
                                                  calibration_coeffs=calibration_coeffs[det.channel_nb],
                                                  background_detector=background_meas.get_detector(det.channel_nb),
                                                  peak_energies=foil_dict["foil"].reaction.product.energy,
                                                  search_width=search_width,
                                                  threshold_overlap=threshold_overlap,
                                                  ax=None,
                                                  plot_peak_area=True,
                                                  plot_initial_guess=True,
                                                  plot_title=f"{name} - {meas_name} - Ch {det.channel_nb}"
            )
            if "Nickel-4" in name:
                ax.set_xlim(600, 1300)
# Out:
# Foil: Aluminum-1 Al27(n,alpha)Na24
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Aluminum1_270deg_short_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Al27', energy=None, intensity=None, half_life=None, atomic_mass=26.9815, abundance=1.0), product=Nuclide(name='Na24', energy=[1368.63], intensity=[0.9994], half_life=53841.6, atomic_mass=23.99096, abundance=1.0), cross_section=np.float64(1.212352e-25), type='(n,alpha)'), mass=1.1022, name='Aluminum-1 Al27(n,alpha)Na24', density=2.7, thickness=0.24384), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cdfaf90>}}
#   Measurement: 1
# Foil: Indium-1 In115(n,n')In115m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/UNFILTERED'), 2: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In115m', energy=[336.24], intensity=[0.43605], half_life=16149.599999999999, atomic_mass=114.9039, abundance=1.0), cross_section=np.float64(6.5895122e-26), type="(n,n')"), mass=0.9404, name="Indium-1 In115(n,n')In115m", density=7.31, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cd09590>, 2: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cd09090>}}
#   Measurement: 1
#   Measurement: 2
# Foil: Indium-1 In115(n,gamma)In116m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_short_count1/UNFILTERED'), 2: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium1_90deg_long_count2/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In116m', energy=[1097.28], intensity=[0.585], half_life=3257.4, atomic_mass=115.9053, abundance=1.0), cross_section=np.float64(9.700996599999999e-28), type='(n,gamma)'), mass=0.9404, name='Indium-1 In115(n,gamma)In116m', density=7.31, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cc1eb10>, 2: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cc1f230>}}
#   Measurement: 1
#   Measurement: 2
# Error fitting peak group: [np.float64(1097.28)]
# Foil: Indium-2 In115(n,n')In115m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In115m', energy=[336.24], intensity=[0.43605], half_life=16149.599999999999, atomic_mass=114.9039, abundance=1.0), cross_section=np.float64(6.5895122e-26), type="(n,n')"), mass=0.7077, name="Indium-2 In115(n,n')In115m", density=7.31, thickness=0.0762), 'distance_to_source': 2.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cf84ef0>}}
#   Measurement: 1
# Foil: Indium-2 In115(n,gamma)In116m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium2_under_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In116m', energy=[1097.28], intensity=[0.585], half_life=3257.4, atomic_mass=115.9053, abundance=1.0), cross_section=np.float64(9.700996599999999e-28), type='(n,gamma)'), mass=0.7077, name='Indium-2 In115(n,gamma)In116m', density=7.31, thickness=0.0762), 'distance_to_source': 2.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cb78e20>}}
#   Measurement: 1
# Foil: Indium-3 In115(n,n')In115m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In115m', energy=[336.24], intensity=[0.43605], half_life=16149.599999999999, atomic_mass=114.9039, abundance=1.0), cross_section=np.float64(6.5895122e-26), type="(n,n')"), mass=0.9412, name="Indium-3 In115(n,n')In115m", density=7.31, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cb78f30>}}
#   Measurement: 1
# Foil: Indium-3 In115(n,gamma)In116m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Indium3_180deg_short_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='In115', energy=None, intensity=None, half_life=None, atomic_mass=114.9039, abundance=0.9572), product=Nuclide(name='In116m', energy=[1097.28], intensity=[0.585], half_life=3257.4, atomic_mass=115.9053, abundance=1.0), cross_section=np.float64(9.700996599999999e-28), type='(n,gamma)'), mass=0.9412, name='Indium-3 In115(n,gamma)In116m', density=7.31, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cc63250>}}
#   Measurement: 1
# Foil: Titanium-1 Ti48(n,p)Sc48
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Titanium_270deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Ti48', energy=None, intensity=None, half_life=None, atomic_mass=47.9479, abundance=0.7372), product=Nuclide(name='Sc48', energy=[983.5, 1037.5, 1312.1], intensity=[1.0, 0.975, 1.0], half_life=157356.0, atomic_mass=47.9522, abundance=1.0), cross_section=np.float64(6.245188e-26), type='(n,p)'), mass=0.5242, name='Titanium-1 Ti48(n,p)Sc48', density=4.502, thickness=0.0889), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cc63050>}}
#   Measurement: 1
# Foil: Nickel-1 Ni58(n,p)Co58
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Nickel1_under_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Ni58', energy=None, intensity=None, half_life=None, atomic_mass=57.9353, abundance=0.6808), product=Nuclide(name='Co58', energy=[810.76], intensity=[0.9945], half_life=6122304.0, atomic_mass=57.9358, abundance=1.0), cross_section=np.float64(3.5531079999999997e-25), type='(n,p)'), mass=1.1359, name='Nickel-1 Ni58(n,p)Co58', density=8.907, thickness=0.20320000000000002), 'distance_to_source': 2.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cb9c500>}}
#   Measurement: 1
# Foil: Molybdenum-1 Mo92(n,p)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Molybdenum_270deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Mo92', energy=None, intensity=None, half_life=None, atomic_mass=91.9068, abundance=0.1465), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=876960.0, atomic_mass=91.9072, abundance=1.0), cross_section=np.float64(7.110941999999999e-26), type='(n,p)'), mass=2.0733, name='Molybdenum-1 Mo92(n,p)Nb92m', density=10.22, thickness=0.20320000000000002), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cb9c6e0>}}
#   Measurement: 1
# Foil: Niobium-12 Nb93(n,2n)Nb92m
# {'measurement_paths': {1: PosixPath('../../data/HPGe/260225_nGen_charac2_HPGe/DAQ/Niobium12_120deg_count1/UNFILTERED')}, 'foil': ActivationFoil(reaction=Reaction(reactant=Nuclide(name='Nb93', energy=None, intensity=None, half_life=None, atomic_mass=92.90637, abundance=1.0), product=Nuclide(name='Nb92m', energy=[934.44], intensity=[0.9915], half_life=885600.0, atomic_mass=None, abundance=1.0), cross_section=4.5966e-25, type='(n,2n)'), mass=1.0944, name='Niobium-12 Nb93(n,2n)Nb92m', density=8.57, thickness=0.10160000000000001), 'distance_to_source': 12.0, 'measurements': {1: <libra_toolbox.neutron_detection.activation_foils.compass.SampleMeasurement object at 0x7fba8cd06dd0>}}
#   Measurement: 1

# %%
from process_foil_data import irradiations, time_generator_off

# %% [markdown]
# ### Niobium Packet #3 Results
#
# The activity of Nb-92m is measured using its 934 keV gamma peak and used to determine the neutron rate during the irradiation. Nb-92m is formed from the Nb-93(n,2n) reaction, which has a threshold energy of 8.9 MeV.
#
# The gamma spectrum obtained from the various measurements of the Niobium Packet #3 after irradiation are used to calculate the neutron rate of the overall irradiation.

# %% [markdown]
# Add the one-group cross sections from the simulation results using the IRDF-II cross section database

# %%
# from process_foil_data import calculate_xs_from_sim
# foil_measurements = calculate_xs_from_sim(foil_measurements)

# %%
from process_foil_data import calculate_neutron_flux_from_foil
foil_rates = {}
foil_rates_err = {}
all_foil_rates = {}
all_foil_rates_err = {}
for foil_name in foil_measurements.keys():
    print(f"\nProcessing foil: {foil_name}")
    gamma_energy = foil_measurements[foil_name]['foil'].reaction.product.energy
    nuclide = foil_measurements[foil_name]['foil'].reaction.reactant.name
    angle = foil_measurements[foil_name]['foil'].angle
    if foil_rates.get(nuclide) is None:
        foil_rates[nuclide] = {}
        foil_rates_err[nuclide] = {}
    if foil_rates[nuclide].get(angle) is None:
        foil_rates[nuclide][angle] = []
        foil_rates_err[nuclide][angle] = []

    if all_foil_rates.get(angle) is None:
        all_foil_rates[angle] = []
        all_foil_rates_err[angle] = []
    detector_efficiency = {}
    detector_efficiency_err = {}
    for ch in channels:
        detector_efficiency[ch], detector_efficiency_err[ch] = \
            calculate_efficiency_at_energy(gamma_energy, ch, method='propagation')
        if len(gamma_energy) == 1:
            print(f"Detector efficiency for Ch {ch} at {gamma_energy[0]} keV: {detector_efficiency[ch]:.6f} ± {detector_efficiency_err[ch]:.6f}")
        else:
            for e,g_erg in enumerate(gamma_energy):
                print(f"Detector efficiency for Ch {ch} at {g_erg} keV: {detector_efficiency[ch][e]:.6f} ± {detector_efficiency_err[ch][e]:.6f}")

    print('\nWith Detector Efficiency Error:')

    neutron_rates, neutron_rates_err = calculate_neutron_flux_from_foil(
                                        foil_measurements,
                                        foil_name,
                                        background_meas,
                                        calibration_coeffs,
                                        efficiency_coeffs,
                                        search_width=search_width,
                                        detector_efficiency=detector_efficiency,
                                        detector_efficiency_err=detector_efficiency_err,
                                        plot_spectra=True
                                        )


    for count_name in neutron_rates.keys():
        print(count_name)
        for ch in np.sort(list(neutron_rates[count_name].keys())):
            neutron_rate = neutron_rates[count_name][ch]
            neutron_rate_err = neutron_rates_err[count_name][ch]
            # print(f"\t Ch {ch}: Neutron rate: {neutron_rate[0]:.3e} +/- {neutron_rate_err[0]:.3e} n/s")
            # if neutron_rate[0] > 0:

            #     all_foil_rates[angle].append(neutron_rate[0])
            #     all_foil_rates_err[angle].append(neutron_rate_err[0])
            #     foil_rates[nuclide][angle].append(neutron_rate[0])
            #     foil_rates_err[nuclide][angle].append(neutron_rate_err[0])
            # else:
            #     print("Negative rate value, skipping addition to totals.")


# print('\nWithout Detector Efficiency Error:')

# neutron_fluxs, neutron_flux_errs = calculate_neutron_flux_from_foil(
#                                     foil_measurements,
#                                     foil_name,
#                                     background_meas,
#                                     calibration_coeffs,
#                                     efficiency_coeffs,
#                                     search_width=search_width,
#                                     detector_efficiency=detector_efficiency,
#                                     detector_efficiency_err=0.0
#                                     )

# for count_name in neutron_rates.keys():
#     print(count_name)
#     for ch in np.sort(list(neutron_rates[count_name].keys())):
#         neutron_rate = neutron_rates[count_name][ch]
#         neutron_rate_err = neutron_rate_errs[count_name][ch]
#         print(f"\t Ch {ch}: Neutron rate: {neutron_rate[0]:.3e} +/- {neutron_rate_err[0]:.3e} n/s")
# Out:
# Processing foil: Aluminum-1 Al27(n,alpha)Na24
# Detector efficiency for Ch 0 at 1368.63 keV: 0.000169 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [1368.63]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 0: [471195.33727412] +/- [52825.277354]
# number_of_decays_measured: [471478.22420864]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [1.58087612e+08]
# number_of_decays_measured: [52856.99154893]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  1.212352e-25
# flux before time and self-attenuation correction: [17723057.22493432]
# Count 1
#
# Processing foil: Indium-1 In115(n,n')In115m
# Detector efficiency for Ch 0 at 336.24 keV: 0.000669 ± 0.000003
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [336.24]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-1 In115(n,n')In115m Count 1 Channel 0: [180408.97974707] +/- [16445.32801618]
# number_of_decays_measured: [413734.61700968]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [1.33090575e+09]
# number_of_decays_measured: [37714.31720256]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [1.21319801e+08]
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [336.24]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-1 In115(n,n')In115m Count 2 Channel 0: [778305.25580564] +/- [34304.42620328]
# number_of_decays_measured: [1784899.10745474]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [5.74168171e+09]
# number_of_decays_measured: [78670.85472601]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [2.5306921e+08]
# Count 1
# Count 2
#
# Processing foil: Indium-1 In115(n,gamma)In116m
# Detector efficiency for Ch 0 at 1097.28 keV: 0.000204 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [1097.28]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-1 In115(n,gamma)In116m Count 1 Channel 0: [406668.02748787] +/- [44695.57620859]
# number_of_decays_measured: [695159.02134679]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [1.51896063e+11]
# number_of_decays_measured: [76402.69437367]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [1.66944083e+10]
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [1097.28]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-1 In115(n,gamma)In116m Count 2 Channel 0: [-68072.58172569] +/- [nan]
# number_of_decays_measured: [-116363.38756529]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [-2.54260392e+10]
# number_of_decays_measured: [nan]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [nan]
# Count 1
# Count 2
#
# Processing foil: Indium-2 In115(n,n')In115m
# Detector efficiency for Ch 0 at 336.24 keV: 0.000669 ± 0.000003
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [336.24]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-2 In115(n,n')In115m Count 1 Channel 0: [2304532.576905] +/- [59668.86702843]
# number_of_decays_measured: [5285019.09621603]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [2.25909985e+10]
# number_of_decays_measured: [136839.50700247]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [5.84925247e+08]
# Count 1
#
# Processing foil: Indium-2 In115(n,gamma)In116m
# Detector efficiency for Ch 0 at 1097.28 keV: 0.000204 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [1097.28]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-2 In115(n,gamma)In116m Count 1 Channel 0: [154593.94376325] +/- [27530.68297222]
# number_of_decays_measured: [264263.15173206]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [7.6729504e+10]
# number_of_decays_measured: [47060.99653371]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [1.36642846e+10]
# Count 1
#
# Processing foil: Indium-3 In115(n,n')In115m
# Detector efficiency for Ch 0 at 336.24 keV: 0.000669 ± 0.000003
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [336.24]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-3 In115(n,n')In115m Count 1 Channel 0: [393397.642692] +/- [24321.72487924]
# number_of_decays_measured: [902184.70976264]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [2.89969023e+09]
# number_of_decays_measured: [55777.3761707]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  6.5895122e-26
# flux before time and self-attenuation correction: [1.79272727e+08]
# Count 1
#
# Processing foil: Indium-3 In115(n,gamma)In116m
# Detector efficiency for Ch 0 at 1097.28 keV: 0.000204 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [1097.28]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Indium-3 In115(n,gamma)In116m Count 1 Channel 0: [473884.7210598] +/- [48260.71391665]
# number_of_decays_measured: [810059.35223898]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [1.76851968e+11]
# number_of_decays_measured: [82496.94686607]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  9.700996599999999e-28
# flux before time and self-attenuation correction: [1.80107141e+10]
# Count 1
#
# Processing foil: Titanium-1 Ti48(n,p)Sc48
# Detector efficiency for Ch 0 at 983.5 keV: 0.000225 ± 0.000001
# Detector efficiency for Ch 0 at 1037.5 keV: 0.000215 ± 0.000001
# Detector efficiency for Ch 0 at 1312.1 keV: 0.000175 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [983.5, 1037.5, 1312.1]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# [983.5]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [1037.5]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# [1312.1]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Titanium-1 Ti48(n,p)Sc48 Count 1 Channel 0: [719583.20457101 746820.61097296 842084.12510685] +/- [56708.69280107 59173.61027202 69501.71201371]
# number_of_decays_measured: 775879.0623620073
# nnumber of atoms in foil:  4.853482895559556e+21
# cross section:  6.245188e-26
# flux before time and self-attenuation correction: 2559735032.86092
# number_of_decays_measured: 62300.42904835433
# nnumber of atoms in foil:  4.853482895559556e+21
# cross section:  6.245188e-26
# flux before time and self-attenuation correction: 205537948.54555878
# Count 1
#
# Processing foil: Nickel-1 Ni58(n,p)Co58
# Detector efficiency for Ch 0 at 810.76 keV: 0.000269 ± 0.000002
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [810.76]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Nickel-1 Ni58(n,p)Co58 Count 1 Channel 0: [8077491.03699401] +/- [179306.74507103]
# number_of_decays_measured: [8122162.93312621]
# nnumber of atoms in foil:  8.038169088345101e+21
# cross section:  3.5531079999999997e-25
# flux before time and self-attenuation correction: [2.8438465e+09]
# number_of_decays_measured: [180298.3861951]
# nnumber of atoms in foil:  8.038169088345101e+21
# cross section:  3.5531079999999997e-25
# flux before time and self-attenuation correction: [63128619.66291737]
# Count 1
#
# Processing foil: Molybdenum-1 Mo92(n,p)Nb92m
# Detector efficiency for Ch 0 at 934.44 keV: 0.000236 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [934.44]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Molybdenum-1 Mo92(n,p)Nb92m Count 1 Channel 0: [284830.42660877] +/- [34798.56504114]
# number_of_decays_measured: [287272.24065433]
# nnumber of atoms in foil:  1.9901823868310072e+21
# cross section:  7.110941999999999e-26
# flux before time and self-attenuation correction: [2.02989534e+09]
# number_of_decays_measured: [35096.88859419]
# nnumber of atoms in foil:  1.9901823868310072e+21
# cross section:  7.110941999999999e-26
# flux before time and self-attenuation correction: [2.47998242e+08]
# Count 1
#
# Processing foil: Niobium-12 Nb93(n,2n)Nb92m
# Detector efficiency for Ch 0 at 934.44 keV: 0.000236 ± 0.000001
#
# With Detector Efficiency Error:
# inside get_gamma_emitted ax:  Axes(0.125,0.11;0.775x0.77)
# [934.44]
# inside get_multipeak_area ax:  Axes(0.125,0.11;0.775x0.77)
# inside fit_peak_gauss ax:  Axes(0.125,0.11;0.775x0.77)
# Plotting initial guess (strategy 1)...
# Successfully fit with strategy 1
# Plotting fitted curve...
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 0: [894546.67631781] +/- [61824.27311521]
# number_of_decays_measured: [902215.50813697]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [2.76695586e+08]
# number_of_decays_measured: [62354.28453375]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  4.5966e-25
# flux before time and self-attenuation correction: [19123097.70462728]
# Count 1

# %%
from process_foil_data import calculate_neutron_flux_from_foil_with_xs
foil_rates = {}
foil_rates_err = {}
gamma_emitted_dict = {}
gamma_emitted_err_dict = {}
factors_dict = {}
all_foil_rates = {}
all_foil_rates_err = {}
for foil_name in foil_measurements.keys():

    neutron_rates, neutron_rates_err, gamma_emitted, gamma_emitted_err, factors = calculate_neutron_flux_from_foil_with_xs(
                                        foil_measurements,
                                        foil_name,
                                        background_meas,
                                        calibration_coeffs,
                                        efficiency_coeffs,
                                        search_width=search_width,
                                        detector_efficiency=detector_efficiency,
                                        detector_efficiency_err=detector_efficiency_err
                                        )
    nuclide = foil_measurements[foil_name]['foil'].reaction.reactant.name
    angle = foil_measurements[foil_name]['foil'].angle
    if foil_rates.get(nuclide) is None:
        foil_rates[nuclide] = {}
        foil_rates_err[nuclide] = {}
        gamma_emitted_dict[nuclide] = {}
        gamma_emitted_err_dict[nuclide] = {}
        factors_dict[nuclide] = {}
    if foil_rates[nuclide].get(angle) is None:
        foil_rates[nuclide][angle] = []
        foil_rates_err[nuclide][angle] = []
        gamma_emitted_dict[nuclide][angle] = {}
        gamma_emitted_err_dict[nuclide][angle] = {}
        factors_dict[nuclide][angle] = {}

    for count_name in neutron_rates.keys():
        print(count_name)
        for reaction in neutron_rates[count_name].keys():
            print(f"\t Reaction: {reaction}")
            gamma_emitted_dict[nuclide][angle][reaction] = []
            gamma_emitted_err_dict[nuclide][angle][reaction] = []
            factors_dict[nuclide][angle][reaction] = []
            for ch in np.sort(list(neutron_rates[count_name][reaction].keys())):
                neutron_rate = neutron_rates[count_name][reaction][ch]
                neutron_rate_err = neutron_rates_err[count_name][reaction][ch]
                
                # neutron_rate may have multiple elements (one per energy group from cross section)
                # but gamma_emitted, gamma_emitted_err, factors only have 1 element (measured value)
                # Find the index with non-zero cross-section (skip zero entries)
                cross_section_array = foil_measurements[foil_name]['foil'].reaction.cross_section
                valid_indices = np.where(cross_section_array != 0)[0]
                
                if len(valid_indices) == 0:
                    print(f"Warning: No non-zero cross-sections found for {reaction}. Skipping.")
                    continue
                
                # Use only the first valid (non-zero) cross-section entry
                valid_idx = valid_indices[0]
                
                rate = np.atleast_1d(neutron_rate)[valid_idx]
                rate_err = np.atleast_1d(neutron_rate_err)[valid_idx]
                
                print(f"\t \tCh {ch}: Neutron rate (using energy group {valid_idx}): {rate * 4*np.pi*11.8**2:.3e} n/s")
                
                # Check if neutron rate is above threshold
                if rate < 1000:
                    print(f"  Neutron rate is {rate:.3e} n/s, which is below threshold. Skipping.")
                    continue
                else:
                    foil_rates[nuclide][angle].append(rate)
                    foil_rates_err[nuclide][angle].append(rate_err)
                    
                    # Now safely append gamma quantities (always 1 element)
                    gamma_emitted_dict[nuclide][angle][reaction].append(gamma_emitted[count_name][reaction][ch])
                    gamma_emitted_err_dict[nuclide][angle][reaction].append(gamma_emitted_err[count_name][reaction][ch])
                    factors_dict[nuclide][angle][reaction].append(factors[count_name][reaction][ch])
# Out:
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Aluminum-1_foil_-90deg_Al27(n,alpha)Na24
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25])}
# inside get_gamma_emitted ax:  None
# [1368.63]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Aluminum-1 Al27(n,alpha)Na24 Count 1 Channel 0: [338612.56182248] +/- [37950.36786547]
# cross section for foil reaction: [0.00000000e+00 1.82434660e-38 7.40939338e-27 8.35914485e-26
#  1.20702258e-25] cm^2
# number_of_decays_measured: [338815.85133328]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 1.82434660e-38 7.40939338e-27 8.35914485e-26
#  1.20702258e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 7.54955409e+20 1.85885708e+09 1.64765698e+08
#  1.14107255e+08]
# number_of_decays_measured: [37973.15175653]
# nnumber of atoms in foil:  2.45999977762541e+22
# cross section:  [0.00000000e+00 1.82434660e-38 7.40939338e-27 8.35914485e-26
#  1.20702258e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 8.46124413e+19 2.08333411e+08 1.84662932e+07
#  1.27886937e+07]
# total efficiency: 1.0
# branching ratio: [0.9994]
# Count 1
# 	 Reaction: Al27(n,alpha)Na24
# 	 	Ch 0: Neutron rate (using energy group 1): 2.347e+21 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-1_foil_90deg_In115(n,n')In115m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {"In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26])}
# inside get_gamma_emitted ax:  None
# [336.24]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-1 In115(n,n')In115m Count 1 Channel 0: [511771.09475508] +/- [46688.73766992]
# cross section for foil reaction: [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26] cm^2
# number_of_decays_measured: [1173652.32141975]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26]
# flux before time and self-attenuation correction: [1.77544668e+10 1.04348640e+09 7.52387541e+08 1.01418263e+09
#  3.79145074e+09]
# number_of_decays_measured: [107071.98181382]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26]
# flux before time and self-attenuation correction: [1.61973518e+09 9.51969799e+07 6.86401106e+07 9.25236055e+07
#  3.45893019e+08]
# total efficiency: 1.0
# branching ratio: [0.43605]
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-1_foil_90deg_In115(n,n')In115m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {"In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26])}
# inside get_gamma_emitted ax:  None
# [336.24]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-1 In115(n,n')In115m Count 2 Channel 0: [2207839.83910175] +/- [97649.3458306]
# cross section for foil reaction: [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26] cm^2
# number_of_decays_measured: [5063272.19149582]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26]
# flux before time and self-attenuation correction: [7.65948284e+10 4.50172130e+09 3.24588709e+09 4.37530146e+09
#  1.63567581e+10]
# number_of_decays_measured: [223940.70824583]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [1.40123358e-26 2.38413794e-25 3.30656127e-25 2.45302515e-25
#  6.56164532e-26]
# flux before time and self-attenuation correction: [3.38767095e+09 1.99104180e+08 1.43560572e+08 1.93512826e+08
#  7.23434146e+08]
# total efficiency: 1.0
# branching ratio: [0.43605]
# Count 1
# 	 Reaction: In115(n,n')In115m
# 	 	Ch 0: Neutron rate (using energy group 0): 6.097e+08 n/s
# Count 2
# 	 Reaction: In115(n,n')In115m
# 	 	Ch 0: Neutron rate (using energy group 0): 6.285e+08 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-1_foil_90deg_In115(n,gamma)In116m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28])}
# inside get_gamma_emitted ax:  None
# [1097.28]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-1 In115(n,gamma)In116m Count 1 Channel 0: [352236.11323159] +/- [38708.4505426]
# cross section for foil reaction: [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28] cm^2
# number_of_decays_measured: [602113.0140711]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28]
# flux before time and self-attenuation correction: [4.84766931e+08 1.05251953e+09 1.80452502e+10 1.56374968e+11
#  1.32047700e+11]
# number_of_decays_measured: [66168.29152582]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28]
# flux before time and self-attenuation correction: [5.32727227e+07 1.15665029e+08 1.98305526e+09 1.71845887e+10
#  1.45111806e+10]
# total efficiency: 1.0
# branching ratio: [0.585]
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-1_foil_90deg_In115(n,gamma)In116m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28])}
# inside get_gamma_emitted ax:  None
# [1097.28]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-1 In115(n,gamma)In116m Count 2 Channel 0: [-58961.16730104] +/- [nan]
# cross section for foil reaction: [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28] cm^2
# number_of_decays_measured: [-100788.32017273]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28]
# flux before time and self-attenuation correction: [-8.11456380e+07 -1.76182334e+08 -3.02061310e+09 -2.61757677e+10
#  -2.21036010e+10]
# number_of_decays_measured: [nan]
# nnumber of atoms in foil:  4.7176019259224464e+21
# cross section:  [2.63283556e-25 1.21262511e-25 7.07283967e-27 8.16186651e-28
#  9.66553466e-28]
# flux before time and self-attenuation correction: [nan nan nan nan nan]
# total efficiency: 1.0
# branching ratio: [0.585]
# Count 1
# 	 Reaction: In115(n,gamma)In116m
# 	 	Ch 0: Neutron rate (using energy group 0): 6.589e+00 n/s
#   Neutron rate is 3.766e-03 n/s, which is below threshold. Skipping.
# Count 2
# 	 Reaction: In115(n,gamma)In116m
# 	 	Ch 0: Neutron rate (using energy group 0): -1.050e+01 n/s
#   Neutron rate is -6.000e-03 n/s, which is below threshold. Skipping.
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-2_foil_underdeg_In115(n,n')In115m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {"In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26])}
# inside get_gamma_emitted ax:  None
# [336.24]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-2 In115(n,n')In115m Count 1 Channel 0: [6537330.68849951] +/- [170957.6120752]
# cross section for foil reaction: [1.54414935e-26 2.35366373e-25 3.30164471e-25 2.67043298e-25
#  6.57365860e-26] cm^2
# number_of_decays_measured: [14992158.44169135]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  [1.54414935e-26 2.35366373e-25 3.30164471e-25 2.67043298e-25
#  6.57365860e-26]
# flux before time and self-attenuation correction: [2.73474599e+11 1.79416294e+10 1.27901595e+10 1.58133766e+10
#  6.42390561e+10]
# number_of_decays_measured: [392059.6538819]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  [1.54414935e-26 2.35366373e-25 3.30164471e-25 2.67043298e-25
#  6.57365860e-26]
# flux before time and self-attenuation correction: [7.15162911e+09 4.69191213e+08 3.34475220e+08 4.13535314e+08
#  1.67991435e+09]
# total efficiency: 1.0
# branching ratio: [0.43605]
# Count 1
# 	 Reaction: In115(n,n')In115m
# 	 	Ch 0: Neutron rate (using energy group 0): 1.163e+10 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-2_foil_underdeg_In115(n,gamma)In116m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28])}
# inside get_gamma_emitted ax:  None
# [1097.28]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-2 In115(n,gamma)In116m Count 1 Channel 0: [133901.77294411] +/- [23844.64172877]
# cross section for foil reaction: [2.02684645e-25 1.21256914e-25 7.50260450e-27 8.57531551e-28
#  9.66660152e-28] cm^2
# number_of_decays_measured: [228891.91956259]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  [2.02684645e-25 1.21256914e-25 7.50260450e-27 8.57531551e-28
#  9.66660152e-28]
# flux before time and self-attenuation correction: [3.18091266e+08 5.31699294e+08 8.59331123e+09 7.51834908e+10
#  6.66958448e+10]
# number_of_decays_measured: [40760.07133123]
# nnumber of atoms in foil:  3.550241262202589e+21
# cross section:  [2.02684645e-25 1.21256914e-25 7.50260450e-27 8.57531551e-28
#  9.66660152e-28]
# flux before time and self-attenuation correction: [5.66443006e+07 9.46826835e+07 1.53025926e+09 1.33883470e+10
#  1.18769042e+10]
# total efficiency: 1.0
# branching ratio: [0.585]
# Count 1
# 	 Reaction: In115(n,gamma)In116m
# 	 	Ch 0: Neutron rate (using energy group 0): 3.521e+01 n/s
#   Neutron rate is 2.012e-02 n/s, which is below threshold. Skipping.
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Indium-3_foil_0deg_In115(n,n')In115m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {"In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26])}
# inside get_gamma_emitted ax:  None
# [336.24]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Indium-3 In115(n,n')In115m Count 1 Channel 0: [1115961.86928617] +/- [69115.65748847]
# cross section for foil reaction: [1.41125124e-26 2.47603561e-25 3.30239333e-25 2.34834170e-25
#  6.14588998e-26] cm^2
# number_of_decays_measured: [2559252.07954632]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  [1.41125124e-26 2.47603561e-25 3.30239333e-25 2.34834170e-25
#  6.14588998e-26]
# flux before time and self-attenuation correction: [3.84076857e+10 2.18909993e+09 1.64132157e+09 2.30813488e+09
#  8.81937264e+09]
# number_of_decays_measured: [158503.97314178]
# nnumber of atoms in foil:  4.7216151985093634e+21
# cross section:  [1.41125124e-26 2.47603561e-25 3.30239333e-25 2.34834170e-25
#  6.14588998e-26]
# flux before time and self-attenuation correction: [2.37873042e+09 1.35579078e+08 1.01653132e+08 1.42951354e+08
#  5.46216458e+08]
# total efficiency: 1.0
# branching ratio: [0.43605]
# Count 1
# 	 Reaction: In115(n,n')In115m
# 	 	Ch 0: Neutron rate (using energy group 0): 5.576e+08 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
# ...
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Nickel-1_foil_underdeg_Ni58(n,p)Co58
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25])}
# inside get_gamma_emitted ax:  None
# [810.76]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Nickel-1 Ni58(n,p)Co58 Count 1 Channel 0: [9219091.66380214] +/- [205141.16139061]
# cross section for foil reaction: [1.14697058e-28 8.57129949e-26 5.34495801e-25 6.34159127e-25
#  3.52526514e-25] cm^2
# number_of_decays_measured: [9270077.08778496]
# nnumber of atoms in foil:  8.038169088345101e+21
# cross section:  [1.14697058e-28 8.57129949e-26 5.34495801e-25 6.34159127e-25
#  3.52526514e-25]
# flux before time and self-attenuation correction: [1.00548114e+13 1.34548710e+10 2.15765453e+09 1.81856137e+09
#  3.27140582e+09]
# number_of_decays_measured: [206275.67761751]
# nnumber of atoms in foil:  8.038169088345101e+21
# cross section:  [1.14697058e-28 8.57129949e-26 5.34495801e-25 6.34159127e-25
#  3.52526514e-25]
# flux before time and self-attenuation correction: [2.23737410e+11 2.99394774e+08 4.80116451e+07 4.04662199e+07
#  7.27945890e+07]
# total efficiency: 1.0
# branching ratio: [0.9945]
# Count 1
# 	 Reaction: Ni58(n,p)Co58
# 	 	Ch 0: Neutron rate (using energy group 0): 1.059e+14 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26])}
# inside get_gamma_emitted ax:  None
# [934.44]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Molybdenum-1 Mo92(n,p)Nb92m Count 1 Channel 0: [284830.42660877] +/- [34798.56504114]
# cross section for foil reaction: [0.00000000e+00 2.62009432e-27 5.95468852e-26 1.09665380e-25
#  7.06044679e-26] cm^2
# number_of_decays_measured: [287272.24065433]
# nnumber of atoms in foil:  1.9901823868310072e+21
# cross section:  [0.00000000e+00 2.62009432e-27 5.95468852e-26 1.09665380e-25
#  7.06044679e-26]
# flux before time and self-attenuation correction: [0.00000000e+00 5.50914061e+10 2.42405090e+09 1.31622833e+09
#  2.04441283e+09]
# number_of_decays_measured: [35096.88859419]
# nnumber of atoms in foil:  1.9901823868310072e+21
# cross section:  [0.00000000e+00 2.62009432e-27 5.95468852e-26 1.09665380e-25
#  7.06044679e-26]
# flux before time and self-attenuation correction: [0.00000000e+00 6.73067798e+09 2.96153377e+08 1.60807459e+08
#  2.49771887e+08]
# total efficiency: 1.0
# branching ratio: [0.9915]
# Count 1
# 	 Reaction: Mo92(n,p)Nb92m
# 	 	Ch 0: Neutron rate (using energy group 1): 5.783e+10 n/s
# Read 25 foil cross-sections from ../../data/processed_data.json
# foil_xs_dict: {'Indium-1_foil_90deg_In115(n,gamma)In116m': array([2.63283556e-25, 1.21262511e-25, 7.07283967e-27, 8.16186651e-28,
#        9.66553466e-28]), 'Indium-2_foil_underdeg_In115(n,gamma)In116m': array([2.02684645e-25, 1.21256914e-25, 7.50260450e-27, 8.57531551e-28,
#        9.66660152e-28]), 'Indium-3_foil_0deg_In115(n,gamma)In116m': array([2.34521688e-25, 1.17053738e-25, 7.22050135e-27, 7.61790917e-28,
#        9.18224379e-28]), 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.75383647e-25,
#        4.59821187e-25]), 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25]), 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.55569194e-25,
#        4.59908848e-25]), 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.22950652e-25,
#        4.57593122e-25]), 'Copper-1_foil_90deg_Cu65(n,2n)Cu64': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 7.84432626e-26,
#        8.90658771e-25]), "Indium-1_foil_90deg_In115(n,n')In115m": array([1.40123358e-26, 2.38413794e-25, 3.30656127e-25, 2.45302515e-25,
#        6.56164532e-26]), "Indium-2_foil_underdeg_In115(n,n')In115m": array([1.54414935e-26, 2.35366373e-25, 3.30164471e-25, 2.67043298e-25,
#        6.57365860e-26]), "Indium-3_foil_0deg_In115(n,n')In115m": array([1.41125124e-26, 2.47603561e-25, 3.30239333e-25, 2.34834170e-25,
#        6.14588998e-26]), 'Indium-1_foil_90deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 2.98592425e-25,
#        1.33727338e-24]), 'Indium-2_foil_underdeg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.31523573e-25,
#        1.33657961e-24]), 'Indium-3_foil_0deg_In115(n,2n)In114m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 3.64119659e-25,
#        1.37020508e-24]), 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24': array([0.00000000e+00, 1.82434660e-38, 7.40939338e-27, 8.35914485e-26,
#        1.20702258e-25]), 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.25978792e-25]), 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.26517684e-25]), 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        6.24957981e-25]), 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.51798085e-25]), 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.02388373e-25]), 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        7.41244788e-25]), 'Nickel-1_foil_underdeg_Ni58(n,p)Co58': array([1.14697058e-28, 8.57129949e-26, 5.34495801e-25, 6.34159127e-25,
#        3.52526514e-25]), 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m': array([0.00000000e+00, 2.62009432e-27, 5.95468852e-26, 1.09665380e-25,
#        7.06044679e-26]), 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27': array([0.00000000e+00, 6.93373912e-28, 3.81247139e-26, 9.38592452e-26,
#        7.47464684e-26]), 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48': array([0.00000000e+00, 9.83558966e-32, 3.47667856e-27, 3.29749173e-26,
#        6.23612040e-26])}
# Looking for cross section with key: Niobium-12_foil_60deg_Nb93(n,2n)Nb92m
# Available keys in foil_xs_dict: ['Indium-1_foil_90deg_In115(n,gamma)In116m', 'Indium-2_foil_underdeg_In115(n,gamma)In116m', 'Indium-3_foil_0deg_In115(n,gamma)In116m', 'Niobium-13_foil_0deg_Nb93(n,2n)Nb92m', 'Niobium-12_foil_60deg_Nb93(n,2n)Nb92m', 'Niobium-11_foil_30deg_Nb93(n,2n)Nb92m', 'Niobium-10_foil_120deg_Nb93(n,2n)Nb92m', 'Copper-1_foil_90deg_Cu65(n,2n)Cu64', "Indium-1_foil_90deg_In115(n,n')In115m", "Indium-2_foil_underdeg_In115(n,n')In115m", "Indium-3_foil_0deg_In115(n,n')In115m", 'Indium-1_foil_90deg_In115(n,2n)In114m', 'Indium-2_foil_underdeg_In115(n,2n)In114m', 'Indium-3_foil_0deg_In115(n,2n)In114m', 'Aluminum-1_foil_-90deg_Al27(n,alpha)Na24', 'Zirconium-3_foil_-90deg_Zr90(n,2n)Zr89', 'Zirconium-2_foil_90deg_Zr90(n,2n)Zr89', 'Zirconium-12_foil_underdeg_Zr90(n,2n)Zr89', 'Zirconium-11_foil_0deg_Zr90(n,2n)Zr89', 'Zirconium-9_foil_60deg_Zr90(n,2n)Zr89', 'Zirconium-10_foil_30deg_Zr90(n,2n)Zr89', 'Nickel-1_foil_underdeg_Ni58(n,p)Co58', 'Molybdenum-1_foil_-90deg_Mo92(n,p)Nb92m', 'Aluminum-1_foil_-90deg_Al27(n,p)Mg27', 'Titanium-1_foil_-90deg_Ti48(n,p)Sc48']
# xs_dict: {'Nb93(n,2n)Nb92m': array([0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.40419820e-25,
#        4.59873338e-25])}
# inside get_gamma_emitted ax:  None
# [934.44]
# inside get_multipeak_area ax:  None
# inside fit_peak_gauss ax:  None
# Successfully fit with strategy 1
# Gamma emitted for Niobium-12 Nb93(n,2n)Nb92m Count 1 Channel 0: [894546.67631781] +/- [61824.27311521]
# cross section for foil reaction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.40419820e-25
#  4.59873338e-25] cm^2
# number_of_decays_measured: [902215.50813697]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.40419820e-25
#  4.59873338e-25]
# flux before time and self-attenuation correction: [0.00000000e+00 0.00000000e+00 0.00000000e+00 9.05754564e+08
#  2.76567225e+08]
# number_of_decays_measured: [62354.28453375]
# nnumber of atoms in foil:  7.093675923405468e+21
# cross section:  [0.00000000e+00 0.00000000e+00 0.00000000e+00 1.40419820e-25
#  4.59873338e-25]
# flux before time and self-attenuation correction: [       0.                0.                0.         62598877.22154798
#  19114226.38336196]
# total efficiency: 1.0
# branching ratio: [0.9915]
# Count 1
# 	 Reaction: Nb93(n,2n)Nb92m
# 	 	Ch 0: Neutron rate (using energy group 3): 3.786e+09 n/s

# %% [markdown]
# ## Angular Characterization Results

# %%
fig, axes = plt.subplots(figsize=(8,6))
formats = {'Nb93': 'x',
           'Zr90': '^',}
for foil_type in foil_rates.keys():
    for angle in foil_rates[foil_type].keys():
        axes.errorbar(
            [angle]*len(foil_rates[foil_type][angle]),
            foil_rates[foil_type][angle],
            yerr=foil_rates_err[foil_type][angle],
            fmt=formats.get(foil_type, 'o'),
            label=f"{foil_type} - {angle}°"
        )
axes.set_xlabel("Foil Angle (degrees)")
axes.set_ylabel("Neutron rate (n/s)")
axes.set_yscale('log')
# axes.set_ylim(bottom=0)
axes.legend()

# %%
import json

def convert_to_serializable(obj):
    """Recursively convert numpy arrays and scalars to JSON-serializable types"""
    if isinstance(obj, dict):
        return {key: convert_to_serializable(value) for key, value in obj.items()}
    elif isinstance(obj, (list, tuple)):
        return [convert_to_serializable(item) for item in obj]
    elif isinstance(obj, np.ndarray):
        return obj.tolist()
    elif isinstance(obj, (np.floating, np.integer)):
        return obj.item()
    elif isinstance(obj, float):
        return float(obj) if not np.isnan(obj) else None
    else:
        return obj

processed_data_file = "../../data/processed_data.json"

processed_data = {'foils': 
                       {'HPGe': {}
                  }
}
for foil_type in foil_rates.keys():
    processed_data['foils']['HPGe'][foil_type] = {}
    for angle in foil_rates[foil_type].keys():
        # Calculate total gamma_emitted measurements across all reactions for this angle
        total_gamma_measurements = sum(len(gamma_emitted_dict[foil_type][angle][reaction]) 
                                       for reaction in gamma_emitted_dict[foil_type][angle].keys())
        
        processed_data['foils']['HPGe'][foil_type][angle] = {
            'rate': float(np.mean(foil_rates[foil_type][angle])),
            'rate_err': float(np.sqrt(np.sum(np.square(foil_rates_err[foil_type][angle]))) / len(foil_rates_err[foil_type][angle])),
            'units': 'n/s',
            'number_of_measurements': len(foil_rates[foil_type][angle]),
            'reactions': {}
        }
        
        # Verify that the total measurements match
        if len(foil_rates[foil_type][angle]) != total_gamma_measurements:
            print(f"Warning: Measurement count mismatch for {foil_type} at {angle}°:")
            print(f"  foil_rates measurements: {len(foil_rates[foil_type][angle])}")
            print(f"  Total gamma_emitted measurements: {total_gamma_measurements}")
            print(f"  Breakdown by reaction:")
            for reaction in gamma_emitted_dict[foil_type][angle].keys():
                n = len(gamma_emitted_dict[foil_type][angle][reaction])
                print(f"    {reaction}: {n} measurements")
        
        for reaction in gamma_emitted_dict[foil_type][angle].keys():
            if np.all(np.array(gamma_emitted_dict[foil_type][angle][reaction])>0):
                processed_data['foils']['HPGe'][foil_type][angle]['reactions'][reaction] = {
                    'gamma_emitted': gamma_emitted_dict[foil_type][angle][reaction],
                    'gamma_emitted_err': gamma_emitted_err_dict[foil_type][angle][reaction],
                    'factors': factors_dict[foil_type][angle][reaction],
                }

# Convert all numpy types to native Python types
processed_data = convert_to_serializable(processed_data)

print("Processed data to be stored:")
print(processed_data)

try:
    with open(processed_data_file, "r") as f:
        existing_data = json.load(f)
except FileNotFoundError:
    print(f"Processed data file not found, creating it in {processed_data_file}")
    existing_data = {}

existing_data.update(processed_data)

with open(processed_data_file, "w") as f:
    json.dump(existing_data, f, indent=4)

print(f"Processed data stored in {processed_data_file}")
# Out:
# Warning: Measurement count mismatch for In115 at 90°:
#   foil_rates measurements: 2
#   Total gamma_emitted measurements: 1
#   Breakdown by reaction:
#     In115(n,n')In115m: 1 measurements
#     In115(n,gamma)In116m: 0 measurements
# Processed data to be stored:
# {'foils': {'HPGe': {'Al27': {-90: {'rate': 1.341407838911237e+18, 'rate_err': 1.5033972948410077e+17, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {'Al27(n,alpha)Na24': {'gamma_emitted': [[338612.5618224782]], 'gamma_emitted_err': [[37950.36786547235]], 'factors': [[1.383677485031149e+25]]}}}}, 'In115': {90: {'rate': 353811.0663620082, 'rate_err': 17768.507921679386, 'units': 'n/s', 'number_of_measurements': 2, 'reactions': {"In115(n,n')In115m": {'gamma_emitted': [[2207839.8391017537]], 'gamma_emitted_err': [[97649.34583059531]], 'factors': [[4.386826994953949e+26]]}, 'In115(n,gamma)In116m': {'gamma_emitted': [], 'gamma_emitted_err': [], 'factors': []}}}, nan: {'rate': 6646955.424386619, 'rate_err': 173824.40648482516, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {"In115(n,n')In115m": {'gamma_emitted': [[6537330.688499513]], 'gamma_emitted_err': [[170957.61207520412]], 'factors': [[6.3692513269394175e+25]]}, 'In115(n,gamma)In116m': {'gamma_emitted': [], 'gamma_emitted_err': [], 'factors': []}}}, 0: {'rate': 318655.49738987675, 'rate_err': 19735.51679548434, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {"In115(n,n')In115m": {'gamma_emitted': [[1115961.8692861728]], 'gamma_emitted_err': [[69115.65748847186]], 'factors': [[2.4815532850218355e+26]]}, 'In115(n,gamma)In116m': {'gamma_emitted': [], 'gamma_emitted_err': [], 'factors': []}}}}, 'Ti48': {-90: {'rate': 348814238878.2049, 'rate_err': 27939582496.571266, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {'Ti48(n,p)Sc48': {'gamma_emitted': [[686910.6739169928, 679601.6685165231, 626459.7191576696]], 'gamma_emitted_err': [[54129.907085741506, 53839.5372615318, 51680.38946559581]], 'factors': [[1.953287304275017e+25, 1.9044551216681416e+25, 1.953287304275017e+25]]}}}}, 'Ni58': {nan: {'rate': 60532074290.53408, 'rate_err': 1346946149.81425, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {'Ni58(n,p)Co58': {'gamma_emitted': [[9219091.66380214]], 'gamma_emitted_err': [[205141.16139061152]], 'factors': [[1.3278539148061815e+24]]}}}}, 'Mo92': {-90: {'rate': 33048759.903826922, 'rate_err': 4037663.5134629873, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {'Mo92(n,p)Nb92m': {'gamma_emitted': [[284830.4266087687]], 'gamma_emitted_err': [[34798.565041139445]], 'factors': [[3.289381808454403e+24]]}}}}, 'Nb93': {60: {'rate': 2163765.348916373, 'rate_err': 149543.0293691205, 'units': 'n/s', 'number_of_measurements': 1, 'reactions': {'Nb93(n,2n)Nb92m': {'gamma_emitted': [[894546.67631781]], 'gamma_emitted_err': [[61824.27311521456]], 'factors': [[2.944180499596765e+24]]}}}}}}}
# Processed data stored in ../../data/processed_data.json

# %%
# DIAGNOSTIC: Understand the data structure mismatch
print("=" * 80)
print("DIAGNOSTIC: Investigating foil_rates vs gamma_emitted_dict lengths")
print("=" * 80)

for foil_type in foil_rates.keys():
    print(f"\nNuclide: {foil_type}")
    for angle in foil_rates[foil_type].keys():
        print(f"  Angle: {angle}°")
        print(f"    Total measurements in foil_rates: {len(foil_rates[foil_type][angle])}")
        print(f"    Reactions in gamma_emitted_dict:")
        
        total_gamma_emitted = 0
        for reaction in gamma_emitted_dict[foil_type][angle].keys():
            n_meas = len(gamma_emitted_dict[foil_type][angle][reaction])
            total_gamma_emitted += n_meas
            print(f"      {reaction}: {n_meas} measurements")
        
        print(f"    Total gamma_emitted across all reactions: {total_gamma_emitted}")
        if len(foil_rates[foil_type][angle]) != total_gamma_emitted:
            print(f"    MISMATCH: {len(foil_rates[foil_type][angle])} != {total_gamma_emitted}")
# Out:
# ================================================================================
# DIAGNOSTIC: Investigating foil_rates vs gamma_emitted_dict lengths
# ================================================================================
#
# Nuclide: Al27
#   Angle: -90°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       Al27(n,alpha)Na24: 1 measurements
#     Total gamma_emitted across all reactions: 1
#
# Nuclide: In115
#   Angle: 90°
#     Total measurements in foil_rates: 2
#     Reactions in gamma_emitted_dict:
#       In115(n,n')In115m: 1 measurements
#       In115(n,gamma)In116m: 0 measurements
#     Total gamma_emitted across all reactions: 1
#     MISMATCH: 2 != 1
#   Angle: nan°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       In115(n,n')In115m: 1 measurements
#       In115(n,gamma)In116m: 0 measurements
#     Total gamma_emitted across all reactions: 1
#   Angle: 0°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       In115(n,n')In115m: 1 measurements
#       In115(n,gamma)In116m: 0 measurements
#     Total gamma_emitted across all reactions: 1
#
# Nuclide: Ti48
#   Angle: -90°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       Ti48(n,p)Sc48: 1 measurements
#     Total gamma_emitted across all reactions: 1
#
# Nuclide: Ni58
#   Angle: nan°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       Ni58(n,p)Co58: 1 measurements
#     Total gamma_emitted across all reactions: 1
#
# Nuclide: Mo92
#   Angle: -90°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       Mo92(n,p)Nb92m: 1 measurements
#     Total gamma_emitted across all reactions: 1
#
# Nuclide: Nb93
#   Angle: 60°
#     Total measurements in foil_rates: 1
#     Reactions in gamma_emitted_dict:
#       Nb93(n,2n)Nb92m: 1 measurements
#     Total gamma_emitted across all reactions: 1
